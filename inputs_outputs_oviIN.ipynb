# %% [markdown]
# # Inputs and outputs to/from oviIN
# This notebook investigates the neurons and cell types that make direct connections with oviIN. All analyses will be done on the right oviIN since that one is more complete. We first get the synaptic weights to and from oviIN and collapse by cell type.

# %%
from neuprint import Client
# remove my token before making notebook public
c = Client('neuprint.janelia.org', dataset='hemibrain:v1.2.1', token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImdnMjExNEBjb2x1bWJpYS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hLS9BT2gxNEdpb1lJLUVPLWdidGxPRTh6SmQ0eF9ZQ1Y4ZHF0YVFjWGlHeG5CMz1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTgxMDUyOTYzNH0.jv9eR0SH5RhfBdXrtp4r-dDFOhcsT8GBbE4v69ysCKs') 
c.fetch_version()

# import important stuff here
import numpy as np
import pandas as pd
import matplotlib

# %%
# load package
import matplotlib
import matplotlib as mpl
matplotlib.use('TkAgg')  # or 'Qt5Agg', 'MacOSX', etc.
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator
# %matplotlib inline

# Set 'pdf.fonttype' to 42 to keep the text editable after exporting to pdf
plt.rcParams['pdf.fonttype'] = 42

# %%
# body IDs of oviINs from Neuprint
oviINr_bodyID = 423101189
oviINl_bodyID = 485934965

# %% [markdown]
# ## inputs to oviINr

# %%
# inputs to oviINr
from neuprint import fetch_simple_connections
ovi_inputs = fetch_simple_connections(None,oviINr_bodyID)
ovi_inputs
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 0      611015907    423101189     287   SMP176     oviIN     SMP176_R
# 1     5813087891    423101189     255   SMP544     oviIN     SMP544_R
# 2     1598011458    423101189     243   LAL134     oviIN     LAL134_R
# 3     5813022375    423101189     236    IB017     oviIN      IB017_R
# 4      448342846    423101189     225   CRE075     oviIN     CRE075_R
# ...          ...          ...     ...      ...       ...          ...
# 2519  5901221890    423101189       1   SLP422     oviIN     SLP422_R
# 2520  5901226036    423101189       1     None     oviIN         None
# 2521  5901230025    423101189       1     None     oviIN         None
# 2522  5901231318    423101189       1     None     oviIN         None
# 2523  7112624972    423101189       1     None     oviIN         None
#
#      instance_post                                       conn_roiInfo
# 0          oviIN_R  {'INP': {'pre': 54, 'post': 53}, 'CRE(R)': {'p...
# 1          oviIN_R  {'LX(R)': {'pre': 66, 'post': 65}, 'LAL(R)': {...
# 2          oviIN_R  {'LX(R)': {'pre': 42, 'post': 42}, 'LAL(R)': {...
# 3          oviIN_R  {'SNP(R)': {'pre': 97, 'post': 97}, 'SMP(R)': ...
# 4          oviIN_R  {'INP': {'pre': 199, 'post': 199}, 'CRE(R)': {...
# ...            ...                                                ...
# 2519       oviIN_R  {'SNP(R)': {'pre': 1, 'post': 1}, 'SMP(R)': {'...
# 2520       oviIN_R  {'SNP(R)': {'pre': 1, 'post': 1}, 'SMP(R)': {'...
# 2521       oviIN_R  {'VMNP': {'pre': 1, 'post': 1}, 'VES(R)': {'pr...
# 2522       oviIN_R  {'SNP(L)': {'pre': 1, 'post': 1}, 'SMP(L)': {'...
# 2523       oviIN_R  {'INP': {'pre': 1, 'post': 1}, 'CRE(R)': {'pre...
#
# [2524 rows x 8 columns]

# %%
# replace None with Unknown
ovi_inputs['type_pre'] = ovi_inputs['type_pre'].fillna('Unknown')

# %% [markdown]
# The majority of inputs (and outputs) come from unannotated cell types. To disregard them in the plots, don't run the cell block above that replaces None with a string and ensures that it is not ignored by groupby.

# %%
# grab only necessary columns
ovi_type_inputs = ovi_inputs[['type_pre','weight']]  

# collapse ovi_inputs by cell type and sort in descending order
ovi_type_inputs = ovi_type_inputs.groupby('type_pre', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)
ovi_type_inputs.head(25)
# Out:
#    type_pre  weight
# 0   Unknown    4307
# 1      FS1A     892
# 2     IB017     370
# 3    SMP052     361
# 4    SMP176     299
# 5      FC2B     290
# 6    SMP383     281
# 7    SMP544     259
# 8    LAL134     247
# 9    SMP550     234
# 10   CRE075     225
# 11   SMP566     203
# 12   LAL022     164
# 13   SMP237     163
# 14     FC2C     161
# 15   SMP551     159
# 16   SMP051     157
# 17   SMP386     156
# 18     pC1e     148
# 19   SMP112     140
# 20     pC1d     140
# 21   SMP153     137
# 22   CRE077     133
# 23   SMP042     132
# 24   SMP185     129

# %%
ovi_input_FS1A = ovi_inputs[ovi_inputs['type_pre']==ovi_type_inputs['type_pre'][0]]

# %%
ovi_input_FS1A
# Out:
#      bodyId_pre  bodyId_post  weight type_pre type_post    instance_pre  \
# 145   983426636    423101189      32     FS1A     oviIN  FS1A(FQ9)_C6_L
# 156  1044918145    423101189      31     FS1A     oviIN  FS1A(FQ9)_C7_R
# 157  1138026774    423101189      31     FS1A     oviIN  FS1A(FQ9)_C8_R
# 166   951808062    423101189      30     FS1A     oviIN  FS1A(FQ9)_C6_R
# 170  1230095228    423101189      29     FS1A     oviIN  FS1A(FQ9)_C9_L
# 187  5813022923    423101189      27     FS1A     oviIN  FS1A(FQ9)_C1_R
# 192   983093876    423101189      26     FS1A     oviIN  FS1A(FQ9)_C8_L
# 193  1106888382    423101189      26     FS1A     oviIN  FS1A(FQ9)_C7_L
# 194  1345061120    423101189      26     FS1A     oviIN  FS1A(FQ9)_C8_L
# 197  5813016900    423101189      26     FS1A     oviIN  FS1A(FQ9)_C5_L
# 201   885257938    423101189      25     FS1A     oviIN  FS1A(FQ9)_C6_L
# 202   915273417    423101189      25     FS1A     oviIN  FS1A(FQ9)_C4_L
# 215  1045141938    423101189      24     FS1A     oviIN  FS1A(FQ9)_C8_L
# 223   983430664    423101189      23     FS1A     oviIN  FS1A(FQ9)_C3_R
# 225  1291374677    423101189      23     FS1A     oviIN  FS1A(FQ9)_C1_R
# 237   890425079    423101189      22     FS1A     oviIN  FS1A(FQ9)_C2_R
# 240  1014465452    423101189      22     FS1A     oviIN  FS1A(FQ9)_C3_L
# 241  1039063931    423101189      22     FS1A     oviIN  FS1A(FQ9)_C5_R
# 253  1195891557    423101189      21     FS1A     oviIN  FS1A(FQ9)_C2_R
# 259  5813130366    423101189      21     FS1A     oviIN  FS1A(FQ9)_C8_R
# 268   915964748    423101189      20     FS1A     oviIN  FS1A(FQ9)_C6_R
# 271  1165305889    423101189      20     FS1A     oviIN  FS1A(FQ9)_C8_R
# 282  1014223948    423101189      19     FS1A     oviIN  FS1A(FQ9)_C2_R
# 283  1014465588    423101189      19     FS1A     oviIN  FS1A(FQ9)_C9_L
# 284  1014474192    423101189      19     FS1A     oviIN  FS1A(FQ9)_C2_L
# 285  1071769518    423101189      19     FS1A     oviIN  FS1A(FQ9)_C4_R
# 309  1071496918    423101189      18     FS1A     oviIN  FS1A(FQ9)_C7_R
# 312  5813065365    423101189      18     FS1A     oviIN  FS1A(FQ9)_C7_L
# 327   940791248    423101189      17     FS1A     oviIN  FS1A(FQ9)_C4_R
# 330   976994022    423101189      17     FS1A     oviIN  FS1A(FQ9)_C5_L
# 331   977697611    423101189      17     FS1A     oviIN  FS1A(FQ9)_C6_L
# 332  1014461486    423101189      17     FS1A     oviIN  FS1A(FQ9)_C3_L
# 333  1039085109    423101189      17     FS1A     oviIN  FS1A(FQ9)_C6_R
# 334  1039426238    423101189      17     FS1A     oviIN  FS1A(FQ9)_C5_R
# 336  1136252170    423101189      17     FS1A     oviIN  FS1A(FQ9)_C3_R
# 357  1014102651    423101189      16     FS1A     oviIN  FS1A(FQ9)_C2_L
# 358  1044800536    423101189      16     FS1A     oviIN  FS1A(FQ9)_C7_L
# 396  1075611602    423101189      14     FS1A     oviIN  FS1A(FQ9)_C8_R
# 415   983067799    423101189      13     FS1A     oviIN  FS1A(FQ9)_C3_L
# 445  1323454861    423101189      12     FS1A     oviIN  FS1A(FQ9)_C1_R
# 513  1014465666    423101189      10     FS1A     oviIN  FS1A(FQ9)_C9_L
# 516  1045268099    423101189      10     FS1A     oviIN  FS1A(FQ9)_C4_R
# 556   946308462    423101189       9     FS1A     oviIN  FS1A(FQ9)_C4_L
# 562  1102804327    423101189       9     FS1A     oviIN  FS1A(FQ9)_C3_R
#
#     instance_post                                       conn_roiInfo
# 145       oviIN_R  {'SNP(R)': {'pre': 25, 'post': 25}, 'SMP(R)': ...
# 156       oviIN_R  {'SNP(R)': {'pre': 25, 'post': 25}, 'SMP(R)': ...
# 157       oviIN_R  {'SNP(R)': {'pre': 21, 'post': 21}, 'SMP(R)': ...
# 166       oviIN_R  {'SNP(R)': {'pre': 25, 'post': 25}, 'SMP(R)': ...
# 170       oviIN_R  {'SNP(R)': {'pre': 19, 'post': 19}, 'SMP(R)': ...
# 187       oviIN_R  {'SNP(R)': {'pre': 24, 'post': 24}, 'SMP(R)': ...
# 192       oviIN_R  {'SNP(R)': {'pre': 26, 'post': 26}, 'SMP(R)': ...
# 193       oviIN_R  {'SNP(R)': {'pre': 25, 'post': 25}, 'SMP(R)': ...
# 194       oviIN_R  {'SNP(R)': {'pre': 25, 'post': 25}, 'SMP(R)': ...
# 197       oviIN_R  {'SNP(R)': {'pre': 24, 'post': 24}, 'SMP(R)': ...
# 201       oviIN_R  {'SNP(R)': {'pre': 22, 'post': 22}, 'SMP(R)': ...
# 202       oviIN_R  {'SNP(R)': {'pre': 21, 'post': 21}, 'SMP(R)': ...
# 215       oviIN_R  {'INP': {'pre': 4, 'post': 4}, 'CRE(R)': {'pre...
# 223       oviIN_R  {'SNP(R)': {'pre': 20, 'post': 20}, 'SMP(R)': ...
# 225       oviIN_R  {'SNP(R)': {'pre': 15, 'post': 15}, 'SMP(R)': ...
# 237       oviIN_R  {'SNP(R)': {'pre': 18, 'post': 17}, 'SMP(R)': ...
# 240       oviIN_R  {'SNP(R)': {'pre': 19, 'post': 19}, 'SMP(R)': ...
# 241       oviIN_R  {'SNP(R)': {'pre': 15, 'post': 15}, 'SMP(R)': ...
# 253       oviIN_R  {'SNP(R)': {'pre': 16, 'post': 16}, 'SMP(R)': ...
# 259       oviIN_R  {'SNP(R)': {'pre': 17, 'post': 17}, 'SMP(R)': ...
# 268       oviIN_R  {'SNP(R)': {'pre': 20, 'post': 20}, 'SMP(R)': ...
# 271       oviIN_R  {'SNP(R)': {'pre': 19, 'post': 19}, 'SMP(R)': ...
# 282       oviIN_R  {'SNP(R)': {'pre': 18, 'post': 18}, 'SMP(R)': ...
# 283       oviIN_R  {'SNP(R)': {'pre': 17, 'post': 17}, 'SMP(R)': ...
# 284       oviIN_R  {'SNP(R)': {'pre': 16, 'post': 16}, 'SMP(R)': ...
# 285       oviIN_R  {'SNP(R)': {'pre': 15, 'post': 15}, 'SMP(R)': ...
# 309       oviIN_R  {'SNP(R)': {'pre': 18, 'post': 18}, 'SMP(R)': ...
# 312       oviIN_R  {'SNP(R)': {'pre': 18, 'post': 18}, 'SMP(R)': ...
# 327       oviIN_R  {'SNP(R)': {'pre': 7, 'post': 8}, 'SMP(R)': {'...
# 330       oviIN_R  {'SNP(R)': {'pre': 17, 'post': 17}, 'SMP(R)': ...
# 331       oviIN_R  {'SNP(R)': {'pre': 17, 'post': 17}, 'SMP(R)': ...
# 332       oviIN_R  {'SNP(R)': {'pre': 14, 'post': 14}, 'SMP(R)': ...
# 333       oviIN_R  {'SNP(R)': {'pre': 14, 'post': 14}, 'SMP(R)': ...
# 334       oviIN_R  {'SNP(R)': {'pre': 17, 'post': 17}, 'SMP(R)': ...
# 336       oviIN_R  {'SNP(R)': {'pre': 16, 'post': 16}, 'SMP(R)': ...
# 357       oviIN_R  {'SNP(R)': {'pre': 15, 'post': 15}, 'SMP(R)': ...
# 358       oviIN_R  {'SNP(L)': {'pre': 3, 'post': 3}, 'SMP(L)': {'...
# 396       oviIN_R  {'SNP(R)': {'pre': 14, 'post': 14}, 'SMP(R)': ...
# 415       oviIN_R  {'SNP(R)': {'pre': 13, 'post': 13}, 'SMP(R)': ...
# 445       oviIN_R  {'SNP(R)': {'pre': 12, 'post': 12}, 'SMP(R)': ...
# 513       oviIN_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...
# 516       oviIN_R  {'SNP(R)': {'pre': 10, 'post': 10}, 'SMP(R)': ...
# 556       oviIN_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...
# 562       oviIN_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...

# %%
# the number of FS1A neurons
len(ovi_input_FS1A)
# Out:
# 44

# %%
from neuprint import fetch_neurons
# fetch FS1A neurons
FS1A_df, FS1A_rois = fetch_neurons('FS1A')
# Out:
#         bodyId        instance  type  pre  post  downstream  upstream  mito  \
# 0    885257938  FS1A(FQ9)_C6_L  FS1A  104   904         668       904   118
# 1    890425079  FS1A(FQ9)_C2_R  FS1A   96  1193         732      1193    94
# 2    915273417  FS1A(FQ9)_C4_L  FS1A   98   878         632       878   101
# 3    915964748  FS1A(FQ9)_C6_R  FS1A   93   786         620       786   101
# 4    940791248  FS1A(FQ9)_C4_R  FS1A   99   965         704       965   104
# 5    946308462  FS1A(FQ9)_C4_L  FS1A   87   711         555       711    90
# 6    951808062  FS1A(FQ9)_C6_R  FS1A  102   931         750       931   110
# 7    976994022  FS1A(FQ9)_C5_L  FS1A   82   455         515       455    78
# 8    977697611  FS1A(FQ9)_C6_L  FS1A   85   892         632       892    86
# 9    983067799  FS1A(FQ9)_C3_L  FS1A   85  1179         664      1179    85
# 10   983093876  FS1A(FQ9)_C8_L  FS1A   86   450         556       450    73
# 11   983426636  FS1A(FQ9)_C6_L  FS1A   90   720         669       720    93
# 12   983430664  FS1A(FQ9)_C3_R  FS1A   95  1310         676      1310    87
# 13  1014102651  FS1A(FQ9)_C2_L  FS1A   89   935         569       935   100
# 14  1014223948  FS1A(FQ9)_C2_R  FS1A   87   677         556       677    82
# 15  1014461486  FS1A(FQ9)_C3_L  FS1A   92  1155         642      1155   100
# 16  1014465452  FS1A(FQ9)_C3_L  FS1A  101  1295         623      1295   115
# 17  1014465588  FS1A(FQ9)_C9_L  FS1A   96   546         618       546    85
# 18  1014465666  FS1A(FQ9)_C9_L  FS1A   96   552         791       552    79
# 19  1014474192  FS1A(FQ9)_C2_L  FS1A  112  1496         718      1496   118
# 20  1039063931  FS1A(FQ9)_C5_R  FS1A   82   628         546       628    86
# 21  1039085109  FS1A(FQ9)_C6_R  FS1A   97   861         736       861    87
# 22  1039426238  FS1A(FQ9)_C5_R  FS1A   76   545         509       545    72
# 23  1044800536  FS1A(FQ9)_C7_L  FS1A   99   709         743       709    85
# 24  1044918145  FS1A(FQ9)_C7_R  FS1A  100  1155         634      1155   104
# 25  1045141938  FS1A(FQ9)_C8_L  FS1A   92   725         613       725    93
# 26  1045268099  FS1A(FQ9)_C4_R  FS1A   88   636         675       636    87
# 27  1071496918  FS1A(FQ9)_C7_R  FS1A   96  1077         591      1077    96
# 28  1071769518  FS1A(FQ9)_C4_R  FS1A   58   521         367       521    80
# 29  1075611602  FS1A(FQ9)_C8_R  FS1A  103   796         795       796    94
# 30  1102804327  FS1A(FQ9)_C3_R  FS1A   89   940         670       940    87
# 31  1106888382  FS1A(FQ9)_C7_L  FS1A   84   577         531       577    71
# 32  1136252170  FS1A(FQ9)_C3_R  FS1A   80   929         561       929    85
# 33  1138026774  FS1A(FQ9)_C8_R  FS1A   95   923         628       923    90
# 34  1165305889  FS1A(FQ9)_C8_R  FS1A   92   814         585       814   103
# 35  1195891557  FS1A(FQ9)_C2_R  FS1A   94   768         567       768    97
# 36  1230095228  FS1A(FQ9)_C9_L  FS1A  101   632         777       632    95
# 37  1291374677  FS1A(FQ9)_C1_R  FS1A  105  1093         714      1093    92
# 38  1323454861  FS1A(FQ9)_C1_R  FS1A   98   926         761       926    78
# 39  1345061120  FS1A(FQ9)_C8_L  FS1A   92   747         561       747    97
# 40  5813016900  FS1A(FQ9)_C5_L  FS1A   95   550         589       550    93
# 41  5813022923  FS1A(FQ9)_C1_R  FS1A   98   965         608       965    96
# 42  5813065365  FS1A(FQ9)_C7_L  FS1A   85   618         596       618    82
# 43  5813130366  FS1A(FQ9)_C8_R  FS1A   88   755         664       755    92
#
#          size  status  cropped     statusLabel cellBodyFiber  somaRadius  \
# 0   334594842  Traced    False  Roughly traced         PDM03       291.0
# 1   322961522  Traced    False  Roughly traced         PDM04       266.5
# 2   303060892  Traced    False  Roughly traced         PDM02       291.0
# 3   278063298  Traced    False  Roughly traced         PDM02       301.0
# 4   319057423  Traced    False  Roughly traced         PDM03       301.0
# 5   263778437  Traced    False  Roughly traced         PDM02       291.0
# 6   315886753  Traced    False  Roughly traced         PDM02       301.0
# 7   248373236  Traced    False  Roughly traced         PDM02       291.0
# 8   265896083  Traced    False  Roughly traced         PDM03       291.0
# 9   270617598  Traced    False  Roughly traced         PDM01       291.0
# 10  224772800  Traced    False  Roughly traced         PDM04       261.5
# 11  273006129  Traced    False  Roughly traced         PDM03       271.0
# 12  317376276  Traced    False  Roughly traced         PDM03       236.0
# 13  287844279  Traced    False  Roughly traced         PDM01       301.0
# 14  296676287  Traced    False  Roughly traced         PDM04       291.5
# 15  282026473  Traced    False  Roughly traced         PDM01       291.0
# 16  303266892  Traced    False  Roughly traced         PDM01       291.0
# 17  243118857  Traced    False  Roughly traced         PDM04       245.0
# 18  245790473  Traced    False  Roughly traced         PDM04       300.0
# 19  367640636  Traced    False  Roughly traced         PDM01       301.0
# 20  250087044  Traced    False  Roughly traced         PDM02       301.0
# 21  267295486  Traced    False  Roughly traced         PDM02       301.0
# 22  217423248  Traced    False  Roughly traced         PDM02       301.0
# 23  287022464  Traced    False  Roughly traced         PDM03       241.0
# 24  281089917  Traced    False  Roughly traced         PDM01       301.0
# 25  251265166  Traced    False  Roughly traced         PDM04       246.5
# 26  245898558  Traced    False  Roughly traced         PDM03       301.0
# 27  281260009  Traced    False  Roughly traced         PDM01       236.0
# 28  132221899  Traced    False  Roughly traced         PDM03         NaN
# 29  270107795  Traced    False  Roughly traced         PDM01       301.0
# 30  291796071  Traced    False  Roughly traced         PDM03       236.0
# 31  204805268  Traced    False  Roughly traced         PDM03       246.0
# 32  260539295  Traced    False  Roughly traced         PDM03       236.0
# 33  269811459  Traced    False  Roughly traced         PDM01       301.0
# 34  272735101  Traced    False  Roughly traced         PDM01       301.0
# 35  301492405  Traced    False  Roughly traced         PDM04       266.5
# 36  263495847  Traced    False  Roughly traced         PDM04       239.5
# 37  327110094  Traced    False  Roughly traced         PDM04       271.0
# 38  282169462  Traced    False  Roughly traced         PDM04       291.5
# 39  269950055  Traced    False  Roughly traced         PDM04       251.5
# 40  256048456  Traced    False  Roughly traced         PDM02       291.0
# 41  307772813  Traced    False  Roughly traced         PDM04       291.5
# 42  211154153  Traced    False  Roughly traced         PDM03       261.0
# 43  281325648  Traced    False  Roughly traced         PDM01       301.0
#
#              somaLocation                                            roiInfo  \
# 0   [31175, 15847, 12384]  {'CX': {'pre': 1, 'post': 797, 'downstream': 5...
# 1    [20445, 9482, 18856]  {'SNP(L)': {'pre': 33, 'post': 35, 'downstream...
# 2   [30385, 16059, 12680]  {'CX': {'post': 811, 'upstream': 811, 'mito': ...
# 3   [22982, 16308, 11568]  {'CX': {'pre': 2, 'post': 724, 'downstream': 1...
# 4   [20210, 12279, 12640]  {'SNP(L)': {'pre': 26, 'post': 19, 'downstream...
# 5   [30697, 16376, 13040]  {'CX': {'pre': 3, 'post': 624, 'downstream': 1...
# 6   [22191, 15887, 12672]  {'SNP(L)': {'pre': 23, 'post': 13, 'downstream...
# 7   [30556, 15740, 11968]  {'SNP(R)': {'pre': 40, 'post': 26, 'downstream...
# 8   [30984, 16100, 11704]  {'CX': {'pre': 1, 'post': 814, 'downstream': 5...
# 9   [29498, 16181, 12232]  {'SNP(R)': {'pre': 48, 'post': 37, 'downstream...
# 10  [32853, 11568, 18616]  {'SNP(R)': {'pre': 54, 'post': 50, 'downstream...
# 11  [30775, 16354, 10640]  {'SNP(L)': {'pre': 19, 'post': 14, 'downstream...
# 12  [16993, 11130, 15072]  {'SNP(R)': {'pre': 37, 'post': 32, 'downstream...
# 13  [26807, 16994, 11456]  {'SNP(R)': {'pre': 45, 'post': 34, 'downstream...
# 14  [18950, 10470, 18776]  {'SNP(L)': {'pre': 36, 'post': 43, 'downstream...
# 15  [28899, 16232, 12088]  {'SNP(R)': {'pre': 37, 'post': 23, 'downstream...
# 16  [28255, 16569, 12008]  {'SNP(L)': {'pre': 25, 'post': 28, 'downstream...
# 17  [33446, 11602, 19792]  {'SNP(R)': {'pre': 49, 'post': 31, 'downstream...
# 18  [33748, 11191, 19440]  {'SNP(R)': {'pre': 45, 'post': 37, 'downstream...
# 19  [27300, 17574, 10448]  {'SNP(L)': {'pre': 31, 'post': 18, 'downstream...
# 20  [19582, 14276, 13168]  {'SNP(R)': {'pre': 28, 'post': 21, 'downstream...
# 21  [22191, 15842, 11760]  {'CX': {'post': 795, 'upstream': 795, 'mito': ...
# 22  [20257, 14057, 12736]  {'CX': {'pre': 1, 'post': 475, 'downstream': 8...
# 23  [33577, 12183, 17312]  {'SNP(L)': {'pre': 24, 'post': 21, 'downstream...
# 24  [23421, 17021, 10288]  {'CX': {'pre': 1, 'post': 1086, 'downstream': ...
# 25  [32764, 10526, 18728]  {'SNP(R)': {'pre': 44, 'post': 31, 'downstream...
# 26  [19913, 12028, 12960]  {'CX': {'pre': 2, 'post': 571, 'downstream': 1...
# 27   [23041, 17479, 8624]  {'SNP(R)': {'pre': 46, 'post': 59, 'downstream...
# 28                   None  {'SNP(R)': {'pre': 33, 'post': 33, 'downstream...
# 29  [23908, 14708, 13792]  {'SNP(R)': {'pre': 55, 'post': 42, 'downstream...
# 30  [16841, 11457, 15872]  {'SNP(L)': {'pre': 32, 'post': 22, 'downstream...
# 31  [33979, 13106, 16592]  {'SNP(R)': {'pre': 45, 'post': 30, 'downstream...
# 32  [18327, 10495, 14552]  {'SNP(R)': {'pre': 39, 'post': 44, 'downstream...
# 33  [23511, 14424, 13664]  {'SNP(L)': {'pre': 26, 'post': 17, 'downstream...
# 34  [23835, 15288, 12336]  {'SNP(L)': {'pre': 32, 'post': 39, 'downstream...
# 35  [19687, 10099, 18784]  {'SNP(L)': {'pre': 29, 'post': 16, 'downstream...
# 36  [33130, 11847, 19080]  {'SNP(L)': {'pre': 17, 'post': 11, 'downstream...
# 37  [17977, 10237, 18000]  {'SNP(L)': {'pre': 22, 'post': 17, 'downstream...
# 38   [18846, 9924, 18448]  {'SNP(L)': {'pre': 44, 'post': 39, 'downstream...
# 39  [32253, 10987, 18680]  {'SNP(R)': {'pre': 52, 'post': 45, 'downstream...
# 40  [30695, 16346, 11672]  {'CX': {'post': 461, 'upstream': 461, 'mito': ...
# 41   [19245, 9744, 18688]  {'SNP(R)': {'pre': 35, 'post': 31, 'downstream...
# 42  [33914, 12153, 17480]  {'SNP(R)': {'pre': 51, 'post': 56, 'downstream...
# 43  [23911, 15546, 13536]  {'SNP(L)': {'pre': 28, 'post': 17, 'downstream...
#
#           notes                                          inputRois  \
# 0   FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 1   FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 2   FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 3   FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 4   FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 5   FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 6   FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 7   FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 8   FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl1, FBl2, FBl...
# 9   FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 10  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl1, FBl2, FBl...
# 11  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 12  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 13  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 14  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 15  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 16  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 17  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 18  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 19  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 20  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 21  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 22  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 23  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 24  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 25  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 26  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 27  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl1, FBl2, FBl...
# 28  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 29  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 30  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 31  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl1, FBl2, FBl...
# 32  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 33  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 34  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 35  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 36  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 37  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 38  FB2-6SMPSMP  [CX, FB, FBl2, FBl3, FBl4, FBl5, FBl6, SMP(L),...
# 39  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 40  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl1, FBl2, FBl...
# 41  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 42  FB2-6SMPSMP  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl3, FBl...
# 43  FB2-6SMPSMP  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
#
#                                            outputRois
# 0   [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 1   [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 2   [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 3   [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl4, INP...
# 4   [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 5   [CRE(-RUB)(L), CRE(L), CX, FB, FBl5, FBl6, INP...
# 6   [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 7   [CRE(-RUB)(L), CRE(L), CX, FB, FBl5, INP, SMP(...
# 8   [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 9   [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 10  [CRE(-RUB)(L), CRE(L), CX, FB, FBl2, FBl5, INP...
# 11  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 12  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 13  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 14  [CRE(-RUB)(L), CRE(L), INP, SMP(L), SMP(R), SN...
# 15  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 16  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 17  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 18  [CRE(-RUB)(L), CRE(L), CX, FB, FBl4, FBl5, INP...
# 19  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 20  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 21  [CRE(-RUB)(L), CRE(L), INP, SMP(L), SMP(R), SN...
# 22  [CRE(-RUB)(L), CRE(L), CX, FB, FBl6, INP, SMP(...
# 23  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 24  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 25  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 26  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 27  [CRE(-RUB)(L), CRE(L), INP, SMP(L), SMP(R), SN...
# 28  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 29  [CRE(-RUB)(L), CRE(L), INP, SMP(L), SMP(R), SN...
# 30  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 31  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 32  [CRE(-RUB)(L), CRE(L), CX, FB, FB-column3, FBl...
# 33  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 34  [CRE(-RUB)(L), CRE(L), INP, SMP(L), SMP(R), SN...
# 35  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 36  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 37  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 38  [CRE(-RUB)(L), CRE(L), CX, FB, FBl4, INP, SMP(...
# 39  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 40  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 41  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...
# 42  [CRE(-RUB)(L), CRE(L), CX, FB, FBl4, INP, SMP(...
# 43  [CRE(-ROB,-RUB)(R), CRE(-RUB)(L), CRE(L), CRE(...

# %%
# the number of FS1As in the Hemibrain
len(FS1A_df)
# Out:
# 44

# %% [markdown]
# There are 44 FS1A neurons in the Hemibrain and all of them synapse onto oviINr. Each one has an average synaptic strength of ~20 with oviINr but there is a range of connection strengths.

# %%
# the average synapse weight from FS1A
ovi_input_FS1A['weight'].describe()
# Out:
# count    44.000000
# mean     20.272727
# std       6.009154
# min       9.000000
# 25%      17.000000
# 50%      19.500000
# 75%      25.000000
# max      32.000000
# Name: weight, dtype: float64

# %%
ovi_input_pC1 = ovi_inputs[ovi_inputs['type_pre'].str.contains('pC1')]
ovi_input_pC1
# Out:
#      bodyId_pre  bodyId_post  weight type_pre type_post   instance_pre  \
# 9     514850616    423101189     148     pC1e     oviIN         pC1e_R
# 20   5813063587    423101189     109     pC1d     oviIN         pC1d_R
# 159  5813013342    423101189      31     pC1d     oviIN  pC1d(PDM09)_L
# 317   359744514    423101189      17     pC1a     oviIN  pC1a(PDM09)_L
# 341  5813046951    423101189      17     pC1a     oviIN         pC1a_R
# 491   392821837    423101189      10     pC1b     oviIN  pC1b(PDM09)_L
# 528   267214250    423101189       9     pC1b     oviIN         pC1b_R
# 541   550319575    423101189       9     pC1c     oviIN  pC1c(PDM09)_L
# 997   267551639    423101189       3     pC1c     oviIN         pC1c_R
#
#     instance_post                                       conn_roiInfo
# 9         oviIN_R  {'SNP(R)': {'pre': 147, 'post': 148}, 'SMP(R)'...
# 20        oviIN_R  {'VMNP': {'pre': 21, 'post': 21}, 'VES(R)': {'...
# 159       oviIN_R  {'SNP(R)': {'pre': 30, 'post': 30}, 'SMP(R)': ...
# 317       oviIN_R  {'SNP(R)': {'pre': 17, 'post': 17}, 'SMP(R)': ...
# 341       oviIN_R  {'SNP(R)': {'pre': 17, 'post': 17}, 'SMP(R)': ...
# 491       oviIN_R  {'SNP(R)': {'pre': 10, 'post': 10}, 'SMP(R)': ...
# 528       oviIN_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...
# 541       oviIN_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...
# 997       oviIN_R  {'SNP(R)': {'pre': 3, 'post': 3}, 'SMP(R)': {'...

# %% [markdown]
# ## outputs from oviINr

# %%
# outputs to oviINr
from neuprint import fetch_simple_connections
ovi_outputs = fetch_simple_connections(oviINr_bodyID,None)
ovi_outputs
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 0      423101189   5813021602     320    oviIN    SMP198      oviIN_R
# 1      423101189    452689494     239    oviIN    SMP550      oviIN_R
# 2      423101189    611629428     238    oviIN    CRE077      oviIN_R
# 3      423101189    542376096     208    oviIN    SMP237      oviIN_R
# 4      423101189   5813021005     199    oviIN    SMP507      oviIN_R
# ...          ...          ...     ...      ...       ...          ...
# 3436   423101189   5901197274       1    oviIN    SMP528      oviIN_R
# 3437   423101189   5901203310       1    oviIN      None      oviIN_R
# 3438   423101189   5901220525       1    oviIN      None      oviIN_R
# 3439   423101189   7112625063       1    oviIN      None      oviIN_R
# 3440   423101189   7112625282       1    oviIN      None      oviIN_R
#
#         instance_post                                       conn_roiInfo
# 0            SMP198_R  {'SNP(R)': {'pre': 276, 'post': 276}, 'SMP(R)'...
# 1            SMP550_R  {'SNP(R)': {'pre': 239, 'post': 239}, 'SMP(R)'...
# 2            CRE077_R  {'SNP(R)': {'pre': 216, 'post': 216}, 'SMP(R)'...
# 3            SMP237_R  {'SNP(R)': {'pre': 203, 'post': 203}, 'SMP(R)'...
# 4            SMP507_R  {'SNP(R)': {'pre': 199, 'post': 199}, 'SMP(R)'...
# ...               ...                                                ...
# 3436  SMP528(PDM24)_L  {'SNP(L)': {'pre': 1, 'post': 1}, 'SMP(L)': {'...
# 3437        (PVM12)_L  {'SNP(L)': {'pre': 1, 'post': 1}, 'SMP(L)': {'...
# 3438             None  {'SNP(R)': {'pre': 1, 'post': 1}, 'SMP(R)': {'...
# 3439             None  {'SNP(R)': {'pre': 1, 'post': 1}, 'SMP(R)': {'...
# 3440             None  {'SNP(L)': {'pre': 1, 'post': 1}, 'SMP(L)': {'...
#
# [3441 rows x 8 columns]

# %%
# replace None with Unknown
ovi_outputs['type_post'] = ovi_outputs['type_post'].fillna('Unknown')

# %%
# grab only necessary columns
ovi_type_outputs = ovi_outputs[['type_post','weight']]  

# collapse ovi_outputs by cell type and sort in descending order
ovi_type_outputs = ovi_type_outputs.groupby('type_post', as_index=False).sum().sort_values(by='weight', ascending=False,ignore_index=True)
ovi_type_outputs.head(30)
# Out:
#    type_post  weight
# 0    Unknown    5236
# 1     SMP550     375
# 2     SMP198     328
# 3     CRE077     278
# 4     SMP254     258
# 5     SMP507     253
# 6     SMP237     225
# 7     CRE022     211
# 8     SMP199     205
# 9     SMP272     198
# 10     IB017     194
# 11    SMP376     185
# 12    SMP007     185
# 13    SMP386     176
# 14    SMP079     176
# 15    SMP464     174
# 16    SLP212     171
# 17    SMP184     171
# 18    SMP471     167
# 19    SMP153     167
# 20      pC1c     163
# 21    SMP077     158
# 22    SMP177     157
# 23    MBON27     156
# 24    LAL182     151
# 25    SMP362     148
# 26      FB5Q     146
# 27    SMP181     144
# 28      FB5Z     143
# 29    MBON04     138

# %%
ovi_output_SMP550 = ovi_outputs[ovi_outputs['type_post']==ovi_type_outputs['type_post'][0]]
ovi_output_SMP550
# Out:
#     bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 1    423101189    452689494     239    oviIN    SMP550      oviIN_R
# 12   423101189    579700707     136    oviIN    SMP550      oviIN_R
#
#       instance_post                                       conn_roiInfo
# 1          SMP550_R  {'SNP(R)': {'pre': 239, 'post': 239}, 'SMP(R)'...
# 12  SMP550(PDM29)_L  {'SNP(L)': {'pre': 136, 'post': 136}, 'SMP(L)'...

# %%
ovi_output_SMP198 = ovi_outputs[ovi_outputs['type_post']==ovi_type_outputs['type_post'][1]]
ovi_output_SMP198
# Out:
#      bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 0     423101189   5813021602     320    oviIN    SMP198      oviIN_R
# 834   423101189    546312597       8    oviIN    SMP198      oviIN_R
#
#        instance_post                                       conn_roiInfo
# 0           SMP198_R  {'SNP(R)': {'pre': 276, 'post': 276}, 'SMP(R)'...
# 834  SMP198(PDL06)_L  {'SNP(L)': {'pre': 8, 'post': 8}, 'SMP(L)': {'...

# %%
ovi_output_pC1 = ovi_outputs[ovi_outputs['type_post'].str.contains('pC1')]
ovi_output_pC1
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 37     423101189    267551639      84    oviIN      pC1c      oviIN_R
# 39     423101189    550319575      79    oviIN      pC1c      oviIN_R
# 84     423101189    514850616      53    oviIN      pC1e      oviIN_R
# 242    423101189   5813063587      27    oviIN      pC1d      oviIN_R
# 268    423101189   5813013342      25    oviIN      pC1d      oviIN_R
# 1563   423101189    267214250       3    oviIN      pC1b      oviIN_R
# 1579   423101189    392821837       3    oviIN      pC1b      oviIN_R
# 3383   423101189   5813046951       1    oviIN      pC1a      oviIN_R
#
#       instance_post                                       conn_roiInfo
# 37           pC1c_R  {'SNP(R)': {'pre': 69, 'post': 69}, 'SMP(R)': ...
# 39    pC1c(PDM09)_L  {'SNP(R)': {'pre': 56, 'post': 56}, 'SMP(R)': ...
# 84           pC1e_R  {'SNP(R)': {'pre': 53, 'post': 53}, 'SMP(R)': ...
# 242          pC1d_R  {'SNP(R)': {'pre': 24, 'post': 24}, 'SMP(R)': ...
# 268   pC1d(PDM09)_L  {'SNP(R)': {'pre': 19, 'post': 19}, 'SMP(R)': ...
# 1563         pC1b_R  {'SNP(L)': {'pre': 2, 'post': 2}, 'SMP(L)': {'...
# 1579  pC1b(PDM09)_L  {'SNP(L)': {'pre': 1, 'post': 1}, 'SMP(L)': {'...
# 3383         pC1a_R  {'SNP(R)': {'pre': 1, 'post': 1}, 'SMP(R)': {'...

# %%
# this only works if Nones were replaced
ovi_output_oviDN = ovi_outputs[ovi_outputs['type_post'].str.contains('oviDN') | (ovi_outputs['type_post'] == 'SLP410')]
ovi_output_oviDN
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 108    423101189    550655668      43    oviIN    oviDNa      oviIN_R
# 153    423101189    519949044      36    oviIN    oviDNb      oviIN_R
# 164    423101189    642763374      35    oviIN    oviDNb      oviIN_R
# 256    423101189    450971893      25    oviIN    SLP410      oviIN_R
# 1870   423101189   5813056909       3    oviIN    SLP410      oviIN_R
#
#         instance_post                                       conn_roiInfo
# 108          oviDNa_R  {'SNP(R)': {'pre': 38, 'post': 38}, 'SMP(R)': ...
# 153          oviDNb_R  {'SNP(L)': {'pre': 8, 'post': 8}, 'SMP(L)': {'...
# 164   oviDNb(PDM15)_L  {'SNP(L)': {'pre': 10, 'post': 10}, 'SMP(L)': ...
# 256          SLP410_R  {'SNP(R)': {'pre': 19, 'post': 19}, 'SMP(R)': ...
# 1870         SLP410_R  {'SNP(R)': {'pre': 3, 'post': 3}, 'SMP(R)': {'...

# %%
ovi_output_oviDN['weight'].sum()
# Out:
# 142

# %% [markdown]
# It is notable that the oviDNs are not among the most prominent outputs; however, if the 3 oviDN types (including SLP410s which are putatively another oviDNa type) are grouped then they collectively make 142 synapses.

# %% [markdown]
# ## investigating FS1A
# These are analyses that Daphna had gotten started to characterize the FS1As and to determine what sets them apart from other fan-shaped body types, particularly in relation to oviIN.

# %%
import numpy as np
from numpy import interp
import hvplot.pandas
import holoviews as hv
import networkx as nx
from networkx.drawing.nx_pydot import write_dot
from matplotlib import pyplot as plt
from tqdm import tqdm
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
from neuprint import connection_table_to_matrix
def connectivity_matrix(input_types, synapse_roi=None):
    """
    Takes in a list of unique bodyIds and fetches connections between those types. 
    Outputs a matrix of the connectivity as well as the connection table.
    Can optionally specify an ROI that the neurons must synapse in to be included.
    """
    conns = fetch_simple_connections(input_types, input_types, rois=synapse_roi)
    conns = conns[['type_pre','type_post','weight']]
    matrix = connection_table_to_matrix(conns, 'type', sort_by='type')
    return matrix, conns

# %%
FB_types = ['vDeltaA-M','hDeltaA-M','FB1A','FB2A','FB6D','FB9C','FC1','FC2A','FC2B','FC2C','FC3','FR1','FR2','FS1A','FS1B',
            'FS2','FS3','FS4A','FS4B','FS4C','PFNm_a','PFNm_b','PFNp_a','PFNp_b','PFNp_c','PFNp_d','PFNp_e','PFNa','PFNv',
            'PFNd','PFR_a','PFR_b','PFL1','PFL2','PFL3','PFGs','SAF']

# %%
#get connections to oviIN from anything else
ovi_inputs = fetch_simple_connections(None,oviINr_bodyID)
#get any type_pre that matches type names of FB neurons
FB_ovi_inputs = ovi_inputs.loc[ovi_inputs['type_pre'].isin(FB_types)]

# %%
#creates list of all unique types that input to ovi
#use this list for the connectivity analysis
FB_ovi_input_types = list(FB_ovi_inputs['bodyId_pre'].unique())

# %%
matrix, FB_conns = connectivity_matrix(FB_ovi_input_types)
# Out:
# /Users/ggutierr/anaconda3/envs/modularity/lib/python3.10/site-packages/neuprint/utils.py:304: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   matrix = agg_weights_df.pivot(col_pre, col_post, weight_col)

# %%
matrix.index = matrix.index.astype(str)
matrix.columns = matrix.columns.astype(str)
heatmap = matrix.hvplot.heatmap(xaxis='top', 
                      cmap=('#f7fbff','#deebf7','#c6dbef','#9ecae1','#6baed6','#4292c6','#2171b5', '#084594')).opts(xrotation=0, clim=(0, 1600))
# Adding labels for axes
heatmap = heatmap.opts(xlabel='Postsynaptic neurons', ylabel='Presynaptic neurons',
                      title='Connectivity matrix for all FB types that output to oviIN',
                      colorbar=True, colorbar_opts={'title': 'Synaptic Weight'})
heatmap
# Out:
# :HeatMap   [columns,index]   (value)
