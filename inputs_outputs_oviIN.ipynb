# %% [markdown]
# # Inputs and outputs to/from oviIN
# This notebook investigates the neurons and cell types that make direct connections with oviIN. All analyses will be done on the right oviIN since that one is more complete. We first get the synaptic weights to and from oviIN and collapse by cell type.

# %%
from neuprint import Client
# remove my token before making notebook public
c = Client('neuprint.janelia.org', dataset='hemibrain:v1.2.1', token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImdnMjExNEBjb2x1bWJpYS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hLS9BT2gxNEdpb1lJLUVPLWdidGxPRTh6SmQ0eF9ZQ1Y4ZHF0YVFjWGlHeG5CMz1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTgxMDUyOTYzNH0.jv9eR0SH5RhfBdXrtp4r-dDFOhcsT8GBbE4v69ysCKs') 
c.fetch_version()

# import important stuff here
import numpy as np
import pandas as pd
import matplotlib

# %%
# load package
import matplotlib
import matplotlib as mpl
matplotlib.use('TkAgg')  # or 'Qt5Agg', 'MacOSX', etc.
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator
# %matplotlib inline

# Set 'pdf.fonttype' to 42 to keep the text editable after exporting to pdf
plt.rcParams['pdf.fonttype'] = 42

# %%
# body IDs of oviINs from Neuprint
oviINr_bodyID = 423101189
oviINl_bodyID = 485934965

# %% [markdown]
# ## inputs to oviINr

# %%
# inputs to oviINr
from neuprint import fetch_simple_connections
ovi_inputs = fetch_simple_connections(None,oviINr_bodyID)
ovi_inputs
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 0      611015907    423101189     287   SMP176     oviIN     SMP176_R
# 1     5813087891    423101189     255   SMP544     oviIN     SMP544_R
# 2     1598011458    423101189     243   LAL134     oviIN     LAL134_R
# 3     5813022375    423101189     236    IB017     oviIN      IB017_R
# 4      448342846    423101189     225   CRE075     oviIN     CRE075_R
# ...          ...          ...     ...      ...       ...          ...
# 2519  5901221890    423101189       1   SLP422     oviIN     SLP422_R
# 2520  5901226036    423101189       1     None     oviIN         None
# 2521  5901230025    423101189       1     None     oviIN         None
# 2522  5901231318    423101189       1     None     oviIN         None
# 2523  7112624972    423101189       1     None     oviIN         None
#
#      instance_post                                       conn_roiInfo
# ...

# %% [markdown]
# Get some info about these neurons. In particular, I'm curious about how many are not Traced.

# %%
from neuprint import fetch_neurons
ovi_in_neurons,_ = fetch_neurons(ovi_inputs['bodyId_pre'])
ovi_in_neurons
# Out:
#           bodyId         instance       type   pre  post  downstream  \
# 0      234630133  SMP184(PDL05)_L     SMP184  1075  2470        7782
# 1      263674097      LHPD2a5_a_R  LHPD2a5_a   133   547        1070
# 2      266187480         SMP349_R     SMP349   190   854        1519
# 3      266187559         SLP399_R     SLP399   216   749        1794
# 4      267214250           pC1b_R       pC1b   816  3187        5440
# ...          ...              ...        ...   ...   ...         ...
# 2519  5901231318             None       None    55    66         542
# 2520  5901232053  SMP272(PDL21)_L     SMP272  1064  1640        7150
# 2521  6400000773         SMP411_R     SMP411   182   522        1545
# 2522  7112622044  LAL137(PVL05)_L     LAL137  1376  2087       11635
# 2523  7112624972             None       None     4    42          19
#
#       upstream  mito        size  status cropped     statusLabel  \
# 0         2470   514  1650479006  Traced    True          Leaves
# ...

# %%
# what's the breakdown of Traced versus other status?
ovi_in_neurons['status'].value_counts()
# Out:
# status
# Traced    2315
# Assign     134
# Orphan      75
# Name: count, dtype: int64

# %% [markdown]
# There are several non-Traced neurons among the inputs to oviIN when those are obtained using fetch_simple_connections. Presumably the same neurons would be returned using fetch_adjacencies and the default options.

# %%
# replace None with Unknown
ovi_inputs['type_pre'] = ovi_inputs['type_pre'].fillna('Unknown')

# %%
# export as csv but only the columns we need
ovi_inputs[['bodyId_pre','type_pre','weight']].to_csv('oviIN_specs/ovi_inputs.csv',index=False)

# %% [markdown]
# The majority of inputs (and outputs) come from unannotated cell types. To disregard them in the plots, don't run the cell block above that replaces None with a string and ensures that it is not ignored by groupby.

# %%
# grab only necessary columns
ovi_type_inputs = ovi_inputs[['type_pre','weight']]  

# collapse ovi_inputs by cell type and sort in descending order
ovi_type_inputs = ovi_type_inputs.groupby('type_pre', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)
ovi_type_inputs.head(25)
# Out:
#    type_pre  weight
# 0   Unknown    4307
# 1      FS1A     892
# 2     IB017     370
# 3    SMP052     361
# 4    SMP176     299
# 5      FC2B     290
# 6    SMP383     281
# 7    SMP544     259
# 8    LAL134     247
# 9    SMP550     234
# 10   CRE075     225
# 11   SMP566     203
# 12   LAL022     164
# 13   SMP237     163
# 14     FC2C     161
# 15   SMP551     159
# 16   SMP051     157
# 17   SMP386     156
# 18     pC1e     148
# 19   SMP112     140
# 20     pC1d     140
# 21   SMP153     137
# 22   CRE077     133
# 23   SMP042     132
# 24   SMP185     129

# %% [markdown]
# ### FS1A is oviIN's top input
# FS1A is oviINr's most prominent input type if we disregard the None types (and we should since those could be a mix of other half-traced cell types).

# %%
ovi_input_FS1A = ovi_inputs[ovi_inputs['type_pre']==ovi_type_inputs['type_pre'][0]]

# %%
ovi_input_FS1A
# Out:
#      bodyId_pre  bodyId_post  weight type_pre type_post    instance_pre  \
# 145   983426636    423101189      32     FS1A     oviIN  FS1A(FQ9)_C6_L
# 156  1044918145    423101189      31     FS1A     oviIN  FS1A(FQ9)_C7_R
# 157  1138026774    423101189      31     FS1A     oviIN  FS1A(FQ9)_C8_R
# 166   951808062    423101189      30     FS1A     oviIN  FS1A(FQ9)_C6_R
# 170  1230095228    423101189      29     FS1A     oviIN  FS1A(FQ9)_C9_L
# 187  5813022923    423101189      27     FS1A     oviIN  FS1A(FQ9)_C1_R
# 192   983093876    423101189      26     FS1A     oviIN  FS1A(FQ9)_C8_L
# 193  1106888382    423101189      26     FS1A     oviIN  FS1A(FQ9)_C7_L
# 194  1345061120    423101189      26     FS1A     oviIN  FS1A(FQ9)_C8_L
# 197  5813016900    423101189      26     FS1A     oviIN  FS1A(FQ9)_C5_L
# 201   885257938    423101189      25     FS1A     oviIN  FS1A(FQ9)_C6_L
# 202   915273417    423101189      25     FS1A     oviIN  FS1A(FQ9)_C4_L
# ...

# %%
# the number of FS1A neurons
len(ovi_input_FS1A)
# Out:
# 44

# %%
from neuprint import fetch_neurons
# fetch FS1A neurons
FS1A_df, FS1A_rois = fetch_neurons('FS1A')

# %%
# the number of FS1As in the Hemibrain
len(FS1A_df)
# Out:
# 44

# %% [markdown]
# There are 44 FS1A neurons in the Hemibrain and all of them synapse onto oviINr. Each one has an average synaptic strength of ~20 with oviINr but there is a range of connection strengths.

# %%
# the average synapse weight from FS1A
ovi_input_FS1A['weight'].describe()
# Out:
# count    852.000000
# mean       5.055164
# std       11.133123
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max      168.000000
# Name: weight, dtype: float64

# %% [markdown]
# Do each of the FS1As have oviIN as their strongest output? No, but most of them do (all but 3). Spot checking those 3 shows that oviINr is 2nd.

# %%
# checking top outputs for each FS1A
top_FS1A_output = FS1A_df[['bodyId','instance']].copy()
top_FS1A_output['top_output'] = ''  # Initialize the 'top_output' column

for i, id in enumerate(top_FS1A_output['bodyId']):
    FS1A_outputs = fetch_simple_connections(id, None)
    top_FS1A_output.loc[i,'top_output'] = FS1A_outputs['type_post'][0]

top_FS1A_output
# Out:
#         bodyId        instance top_output
# 0    885257938  FS1A(FQ9)_C6_L      oviIN
# 1    890425079  FS1A(FQ9)_C2_R      oviIN
# 2    915273417  FS1A(FQ9)_C4_L      oviIN
# 3    915964748  FS1A(FQ9)_C6_R      oviIN
# 4    940791248  FS1A(FQ9)_C4_R      oviIN
# 5    946308462  FS1A(FQ9)_C4_L     LAL022
# 6    951808062  FS1A(FQ9)_C6_R      oviIN
# 7    976994022  FS1A(FQ9)_C5_L      oviIN
# 8    977697611  FS1A(FQ9)_C6_L      oviIN
# 9    983067799  FS1A(FQ9)_C3_L      oviIN
# 10   983093876  FS1A(FQ9)_C8_L      oviIN
# 11   983426636  FS1A(FQ9)_C6_L      oviIN
# 12   983430664  FS1A(FQ9)_C3_R      oviIN
# 13  1014102651  FS1A(FQ9)_C2_L      oviIN
# 14  1014223948  FS1A(FQ9)_C2_R      oviIN
# 15  1014461486  FS1A(FQ9)_C3_L      oviIN
# 16  1014465452  FS1A(FQ9)_C3_L      oviIN
# 17  1014465588  FS1A(FQ9)_C9_L      oviIN
# 18  1014465666  FS1A(FQ9)_C9_L      oviIN
# 19  1014474192  FS1A(FQ9)_C2_L      oviIN
# 20  1039063931  FS1A(FQ9)_C5_R      oviIN
# ...

# %%
fetch_simple_connections(946308462, None, min_weight=9)
# Out:
#    bodyId_pre  bodyId_post  weight type_pre type_post    instance_pre  \
# 0   946308462    700486220      10     FS1A    LAL022  FS1A(FQ9)_C4_L
# 1   946308462    423101189       9     FS1A     oviIN  FS1A(FQ9)_C4_L
# 2   946308462    485934965       9     FS1A     oviIN  FS1A(FQ9)_C4_L
#
#      instance_post                                       conn_roiInfo
# 0  LAL022(ADM05)_L  {'SNP(L)': {'pre': 8, 'post': 8}, 'SMP(L)': {'...
# 1          oviIN_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...
# 2          oviIN_L  {'SNP(L)': {'pre': 7, 'post': 7}, 'SMP(L)': {'...

# %%
fetch_simple_connections(1102804327, None, min_weight=9)
# Out:
#    bodyId_pre  bodyId_post  weight type_pre type_post    instance_pre  \
# 0  1102804327    361040812      14     FS1A    SMP081  FS1A(FQ9)_C3_R
# 1  1102804327    485934965      11     FS1A     oviIN  FS1A(FQ9)_C3_R
# 2  1102804327    423101189       9     FS1A     oviIN  FS1A(FQ9)_C3_R
#
#      instance_post                                       conn_roiInfo
# 0  SMP081(ADM04)_L  {'SNP(L)': {'pre': 12, 'post': 12}, 'SMP(L)': ...
# 1          oviIN_L  {'SNP(L)': {'pre': 9, 'post': 9}, 'SMP(L)': {'...
# 2          oviIN_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...

# %% [markdown]
# This one seems to be an outlier since LAL182 isn't even in the top 20 outputs of FS1A as a group.

# %%
fetch_simple_connections(1323454861, None, min_weight=9)
# Out:
#    bodyId_pre  bodyId_post  weight type_pre type_post    instance_pre  \
# 0  1323454861    701345660      16     FS1A    LAL182  FS1A(FQ9)_C1_R
# 1  1323454861    423101189      12     FS1A     oviIN  FS1A(FQ9)_C1_R
# 2  1323454861    485934965       9     FS1A     oviIN  FS1A(FQ9)_C1_R
# 3  1323454861    609310926       9     FS1A    SMP144  FS1A(FQ9)_C1_R
# 4  1323454861    730497472       9     FS1A    LAL022  FS1A(FQ9)_C1_R
# 5  1323454861   1262170241       9     FS1A      None  FS1A(FQ9)_C1_R
# 6  1323454861   5901193890       9     FS1A    SMP150  FS1A(FQ9)_C1_R
#
#      instance_post                                       conn_roiInfo
# 0         LAL182_R  {'SNP(R)': {'pre': 16, 'post': 16}, 'SMP(R)': ...
# 1          oviIN_R  {'SNP(R)': {'pre': 12, 'post': 12}, 'SMP(R)': ...
# 2          oviIN_L  {'SNP(L)': {'pre': 6, 'post': 7}, 'SMP(L)': {'...
# 3         SMP144_R  {'SNP(R)': {'pre': 9, 'post': 9}, 'SMP(R)': {'...
# ...

# %% [markdown]
# If we do the same thing but collapse FS1A's outputs by type, oviIN is the top output less often. It is sometimes LAL022 or FS1A itself.

# %%
# checking top output types for each FS1A
top_FS1A_output_type = FS1A_df[['bodyId','instance']].copy()
top_FS1A_output_type['top_output'] = ''  # Initialize the 'top_output' column

for i, id in enumerate(top_FS1A_output_type['bodyId']):
    FS1A_outputs = fetch_simple_connections(id, None)
    FS1A_outputs = FS1A_outputs[['type_post','weight']].groupby('type_post', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)
    top_FS1A_output_type.loc[i,'top_output'] = FS1A_outputs['type_post'][0]

top_FS1A_output_type
# Out:
#         bodyId        instance top_output
# 0    885257938  FS1A(FQ9)_C6_L       FS1A
# 1    890425079  FS1A(FQ9)_C2_R      oviIN
# 2    915273417  FS1A(FQ9)_C4_L      oviIN
# 3    915964748  FS1A(FQ9)_C6_R       FS1A
# 4    940791248  FS1A(FQ9)_C4_R      oviIN
# 5    946308462  FS1A(FQ9)_C4_L       FS1A
# 6    951808062  FS1A(FQ9)_C6_R      oviIN
# 7    976994022  FS1A(FQ9)_C5_L       FS1A
# 8    977697611  FS1A(FQ9)_C6_L      oviIN
# 9    983067799  FS1A(FQ9)_C3_L     LAL022
# 10   983093876  FS1A(FQ9)_C8_L       FS1A
# 11   983426636  FS1A(FQ9)_C6_L      oviIN
# 12   983430664  FS1A(FQ9)_C3_R       FS1A
# 13  1014102651  FS1A(FQ9)_C2_L     LAL022
# 14  1014223948  FS1A(FQ9)_C2_R      oviIN
# 15  1014461486  FS1A(FQ9)_C3_L       FS1A
# 16  1014465452  FS1A(FQ9)_C3_L       FS1A
# 17  1014465588  FS1A(FQ9)_C9_L       FS1A
# 18  1014465666  FS1A(FQ9)_C9_L     LAL022
# 19  1014474192  FS1A(FQ9)_C2_L       FS1A
# 20  1039063931  FS1A(FQ9)_C5_R      oviIN
# ...

# %% [markdown]
# However, if we group all the output weights for all FS1As, then oviIN is the top output type of FS1A as a group - closely followed by the FS1As themselves due to their strong recurrent connections.

# %%
FS1A_outputs = fetch_simple_connections('FS1A', None)

# %%
FS1A_type_outputs = FS1A_outputs[['type_post','weight']].groupby('type_post', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)

# %%
FS1A_type_outputs.head(20)
# Out:
#    type_post  weight
# 0      oviIN    1589
# 1       FS1A    1581
# 2     LAL022     907
# 3     SMP081     595
# 4     CRE040     546
# 5     CRE093     448
# 6     CRE102     377
# 7     SMP386     369
# 8       FB5Q     302
# 9     SMP204     300
# 10    SMP376     270
# 11    MBON27     265
# 12    CRE095     236
# 13      FB5F     198
# 14    SMP144     187
# 15    SMP185     183
# 16    CRE074     173
# 17    SMP048     166
# 18    SMP150     161
# 19      FC2C     157

# %% [markdown]
# Took a peak at pC1 inputs. pC1d-e are the strongest pC1 inputs to oviINr. These are the ones with persistent activity that are related to aggression (Deutsch et al., 2020).

# %%
ovi_input_pC1 = ovi_inputs[ovi_inputs['type_pre'].str.contains('pC1')]
ovi_input_pC1
# Out:
#      bodyId_pre  bodyId_post  weight type_pre type_post   instance_pre  \
# 9     514850616    423101189     148     pC1e     oviIN         pC1e_R
# 20   5813063587    423101189     109     pC1d     oviIN         pC1d_R
# 159  5813013342    423101189      31     pC1d     oviIN  pC1d(PDM09)_L
# 317   359744514    423101189      17     pC1a     oviIN  pC1a(PDM09)_L
# 341  5813046951    423101189      17     pC1a     oviIN         pC1a_R
# 491   392821837    423101189      10     pC1b     oviIN  pC1b(PDM09)_L
# 528   267214250    423101189       9     pC1b     oviIN         pC1b_R
# 541   550319575    423101189       9     pC1c     oviIN  pC1c(PDM09)_L
# 997   267551639    423101189       3     pC1c     oviIN         pC1c_R
#
#     instance_post                                       conn_roiInfo
# 9         oviIN_R  {'SNP(R)': {'pre': 147, 'post': 148}, 'SMP(R)'...
# 20        oviIN_R  {'VMNP': {'pre': 21, 'post': 21}, 'VES(R)': {'...
# ...

# %% [markdown]
# ## outputs from oviINr

# %%
# outputs to oviINr
from neuprint import fetch_simple_connections
ovi_outputs = fetch_simple_connections(oviINr_bodyID,None)
ovi_outputs
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 0      423101189   5813021602     320    oviIN    SMP198      oviIN_R
# 1      423101189    452689494     239    oviIN    SMP550      oviIN_R
# 2      423101189    611629428     238    oviIN    CRE077      oviIN_R
# 3      423101189    542376096     208    oviIN    SMP237      oviIN_R
# 4      423101189   5813021005     199    oviIN    SMP507      oviIN_R
# ...          ...          ...     ...      ...       ...          ...
# 3436   423101189   5901197274       1    oviIN    SMP528      oviIN_R
# 3437   423101189   5901203310       1    oviIN      None      oviIN_R
# 3438   423101189   5901220525       1    oviIN      None      oviIN_R
# 3439   423101189   7112625063       1    oviIN      None      oviIN_R
# 3440   423101189   7112625282       1    oviIN      None      oviIN_R
#
#         instance_post                                       conn_roiInfo
# ...

# %%
# replace None with Unknown
ovi_outputs['type_post'] = ovi_outputs['type_post'].fillna('Unknown')

# %%
# grab only necessary columns
ovi_type_outputs = ovi_outputs[['type_post','weight']]  

# collapse ovi_outputs by cell type and sort in descending order
ovi_type_outputs = ovi_type_outputs.groupby('type_post', as_index=False).sum().sort_values(by='weight', ascending=False,ignore_index=True)
ovi_type_outputs.head(30)
# Out:
#    type_post  weight
# 0    Unknown    5236
# 1     SMP550     375
# 2     SMP198     328
# 3     CRE077     278
# 4     SMP254     258
# 5     SMP507     253
# 6     SMP237     225
# 7     CRE022     211
# 8     SMP199     205
# 9     SMP272     198
# 10     IB017     194
# 11    SMP376     185
# 12    SMP007     185
# 13    SMP386     176
# 14    SMP079     176
# 15    SMP464     174
# 16    SLP212     171
# 17    SMP184     171
# 18    SMP471     167
# 19    SMP153     167
# 20      pC1c     163
# 21    SMP077     158
# 22    SMP177     157
# 23    MBON27     156
# 24    LAL182     151
# 25    SMP362     148
# 26      FB5Q     146
# 27    SMP181     144
# 28      FB5Z     143
# 29    MBON04     138

# %% [markdown]
# The pair of SMP550 neurons (putative oviENs) are the strongest output from oviIN, closely followed by the SMP198. The left SMP198 has far fewer synapses with oviIN than the right one and this makes me think that if the left side were more complete that SMP198 might be the largest output. This also makes me skeptical about whether the real oviENs might be SMP198. I wonder how Nojima et al determined that SMP550 were the oviENs.

# %%
ovi_output_SMP550 = ovi_outputs[ovi_outputs['type_post']==ovi_type_outputs['type_post'][0]]
ovi_output_SMP550
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 38     423101189    550081317      84    oviIN   Unknown      oviIN_R
# 56     423101189    517242832      69    oviIN   Unknown      oviIN_R
# 63     423101189    550301858      63    oviIN   Unknown      oviIN_R
# 70     423101189    613175370      59    oviIN   Unknown      oviIN_R
# 89     423101189    799945378      51    oviIN   Unknown      oviIN_R
# ...          ...          ...     ...      ...       ...          ...
# 3434   423101189   5813133903       1    oviIN   Unknown      oviIN_R
# 3437   423101189   5901203310       1    oviIN   Unknown      oviIN_R
# 3438   423101189   5901220525       1    oviIN   Unknown      oviIN_R
# 3439   423101189   7112625063       1    oviIN   Unknown      oviIN_R
# 3440   423101189   7112625282       1    oviIN   Unknown      oviIN_R
#
#      instance_post                                       conn_roiInfo
# ...

# %%
ovi_output_SMP198 = ovi_outputs[ovi_outputs['type_post']==ovi_type_outputs['type_post'][1]]
ovi_output_SMP198
# Out:
#     bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 1    423101189    452689494     239    oviIN    SMP550      oviIN_R
# 12   423101189    579700707     136    oviIN    SMP550      oviIN_R
#
#       instance_post                                       conn_roiInfo
# 1          SMP550_R  {'SNP(R)': {'pre': 239, 'post': 239}, 'SMP(R)'...
# 12  SMP550(PDM29)_L  {'SNP(L)': {'pre': 136, 'post': 136}, 'SMP(L)'...

# %% [markdown]
# pC1c is the strongest output from oviINr among the pC1 group. The pC1e and pC1d receive moderate connections from oviIN making these types quite recurrent with oviIN. The pC1a and pC1b types get very weak connections which is weird because I think of pC1a-c as a group. Deutsch says that pC1a controls females receptivity and cites Wang. Also says that pC1a targets pC1d and pC1e.

# %%
ovi_output_pC1 = ovi_outputs[ovi_outputs['type_post'].str.contains('pC1')]
ovi_output_pC1
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 37     423101189    267551639      84    oviIN      pC1c      oviIN_R
# 39     423101189    550319575      79    oviIN      pC1c      oviIN_R
# 84     423101189    514850616      53    oviIN      pC1e      oviIN_R
# 242    423101189   5813063587      27    oviIN      pC1d      oviIN_R
# 268    423101189   5813013342      25    oviIN      pC1d      oviIN_R
# 1563   423101189    267214250       3    oviIN      pC1b      oviIN_R
# 1579   423101189    392821837       3    oviIN      pC1b      oviIN_R
# 3383   423101189   5813046951       1    oviIN      pC1a      oviIN_R
#
#       instance_post                                       conn_roiInfo
# 37           pC1c_R  {'SNP(R)': {'pre': 69, 'post': 69}, 'SMP(R)': ...
# 39    pC1c(PDM09)_L  {'SNP(R)': {'pre': 56, 'post': 56}, 'SMP(R)': ...
# 84           pC1e_R  {'SNP(R)': {'pre': 53, 'post': 53}, 'SMP(R)': ...
# ...

# %% [markdown]
# The oviDNs as a group only receice moderate synapses from oviIN.

# %%
# this only works if Nones were replaced
ovi_output_oviDN = ovi_outputs[ovi_outputs['type_post'].str.contains('oviDN') | (ovi_outputs['type_post'] == 'SLP410')]
ovi_output_oviDN
# Out:
#       bodyId_pre  bodyId_post  weight type_pre type_post instance_pre  \
# 108    423101189    550655668      43    oviIN    oviDNa      oviIN_R
# 153    423101189    519949044      36    oviIN    oviDNb      oviIN_R
# 164    423101189    642763374      35    oviIN    oviDNb      oviIN_R
# 256    423101189    450971893      25    oviIN    SLP410      oviIN_R
# 1870   423101189   5813056909       3    oviIN    SLP410      oviIN_R
#
#         instance_post                                       conn_roiInfo
# 108          oviDNa_R  {'SNP(R)': {'pre': 38, 'post': 38}, 'SMP(R)': ...
# 153          oviDNb_R  {'SNP(L)': {'pre': 8, 'post': 8}, 'SMP(L)': {'...
# 164   oviDNb(PDM15)_L  {'SNP(L)': {'pre': 10, 'post': 10}, 'SMP(L)': ...
# 256          SLP410_R  {'SNP(R)': {'pre': 19, 'post': 19}, 'SMP(R)': ...
# 1870         SLP410_R  {'SNP(R)': {'pre': 3, 'post': 3}, 'SMP(R)': {'...

# %%
ovi_output_oviDN['weight'].sum()
# Out:
# 142

# %% [markdown]
# It is notable that the oviDNs are not among the most prominent outputs; however, if the 3 oviDN types (including SLP410s which are putatively another oviDNa type) are grouped then they collectively make 142 synapses.

# %% [markdown]
# ## investigating FS1A and Fan-shaped body
# These are analyses that Daphna had gotten started to characterize the FS1As and to determine what sets them apart from other fan-shaped body types, particularly in relation to oviIN.

# %%
import numpy as np
from numpy import interp
import hvplot.pandas
import holoviews as hv
import networkx as nx
from networkx.drawing.nx_pydot import write_dot
from matplotlib import pyplot as plt
from tqdm import tqdm
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
from neuprint import connection_table_to_matrix
def connectivity_matrix(input_types, synapse_roi=None):
    """
    Takes in a list of unique bodyIds and fetches connections between those types. 
    Outputs a matrix of the connectivity as well as the connection table.
    Can optionally specify an ROI that the neurons must synapse in to be included.
    """
    conns = fetch_simple_connections(input_types, input_types, rois=synapse_roi)
    conns = conns[['type_pre','type_post','weight']]
    matrix = connection_table_to_matrix(conns, 'type', sort_by='type')
    return matrix, conns

# %% [markdown]
# The lists of FB types below are from Hulse et al. (2022). They come from Tables 2-3 and some additional info from fig. 28, supplement 1.

# %%
# FB types
FB_intrinsic = ['vDeltaA_a','vDeltaA_b','vDeltaB','vDeltaC','vDeltaD','vDeltaE','vDeltaF','vDeltaG','vDeltaH','vDeltaI','vDeltaJ','vDeltaK','vDeltaL','vDeltaM','hDeltaA','hDeltaB','hDeltaC','hDeltaD','hDeltaE','hDeltaF','hDeltaG','hDeltaH','hDeltaI','hDeltaJ','hDeltaK','hDeltaL','hDeltaM']
FB_columnar = ['FR1','FR2','EL','FC1A','FC1B','FC1C','FC1D','FC1E','FC1F','FC2A','FC2B','FC2C','FC3','FS1A','FS1B','FS2','FS3','FS4A','FS4B','FS4C']
FB_tangentials = ['FB1A','FB1B','FB1C','FB1D','FB1E_a','FB1E_b','FB1F','FB1G','FB1H','FB1I','FB1J','FB2A','FB2B_a','FB2B_b','FB2C','FB2D','FB2E','FB2F_a','FB2F_b','FB2F_c','FB2G_a','FB2G_b','FB2H_a','FB2H_b','FB2I_a','FB2I_b','FB2J','FB2K','FB2L','FB2M','FB3A','FB3B','FB3C','FB3D','FB3E','FB4A','FB4B','FB4C','FB4D','FB4E','FB4F_a','FB4F_b','FB4G','FB4H','FB4I','FB4J','FB4K','FB4L','FB4M','FB4N','FB4O','FB4P_a','FB4P_b','FB4Q_a','FB4Q_b','FB4R','FB4X','FB4Y','FB4Z','FB5A','FB5B','FB5C','FB5D','FB5E','FB5F','FB5G','FB5H','FB5I','FB5J','FB5K','FB5L','FB5M','FB5N','FB5O','FB5P','FB5Q','FB5R','FB5S','FB5T','FB5U','FB5V','FB5W','FB5X','FB5Y','FB5Z','FB5AA','FB5AB','FB6A','FB6B','FB6C_a','FB6C_b','FB6D','FB6E','FB6F','FB6G','FB6H','FB6I','FB6J','FB6K','FB6L','FB6M','FB6N','FB6O','FB6P','FB6Q','FB6R','FB6S','FB6T','FB6U','FB6V','FB6W','FB6X','FB6Y','FB6Z','FB7A','FB7B','FB7C','FB7D','FB7E','FB7F','FB7G','FB7H','FB7I','FB7J','FB7K','FB7L','FB7M','FB8A','FB8B','FB8C','FB8D','FB8E','FB8F_a','FB8F_b','FB8G','FB8H','FB8I','FB9A','FB9B_a','FB9B_b','FB9B_c','FB9B_d','FB9B_e','FB9C_a','FB9C_b']
FB_PFtypes = ['PFR_a','PFR_b','PFL1','PFL2','PFL3','PFGs']

FB_types = FB_intrinsic + FB_columnar + FB_tangentials + FB_PFtypes
FB_output_types = FB_columnar + FB_PFtypes

# %%
FB_types = ['vDeltaA-M','hDeltaA-M','FB1A','FB2A','FB6D','FB9C','FC1','FC2A','FC2B','FC2C','FC3','FR1','FR2','FS1A','FS1B',
            'FS2','FS3','FS4A','FS4B','FS4C','PFNm_a','PFNm_b','PFNp_a','PFNp_b','PFNp_c','PFNp_d','PFNp_e','PFNa','PFNv',
            'PFNd','PFR_a','PFR_b','PFL1','PFL2','PFL3','PFGs','SAF']

# %% [markdown]
# Daphna's plot only includes individual neurons that input to oviINr rather than grabbing the entire cell type group. She then displays them by group but they are actually partial groups.

# %%
#get connections to oviIN from anything else
ovi_inputs = fetch_simple_connections(None,oviINr_bodyID)
#get any type_pre that matches type names of FB neurons
FB_ovi_inputs = ovi_inputs.loc[ovi_inputs['type_pre'].isin(FB_output_types)]

# %%
FB_ovi_inputs = FB_ovi_inputs[FB_ovi_inputs['weight']>3]

# %%
#creates list of all unique types that input to ovi
#use this list for the connectivity analysis
FB_ovi_input_types = list(FB_ovi_inputs['bodyId_pre'].unique())

# %%
matrix, FB_conns = connectivity_matrix(FB_ovi_input_types)
# Out:
# /Users/ggutierr/anaconda3/envs/modularity/lib/python3.10/site-packages/neuprint/utils.py:304: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   matrix = agg_weights_df.pivot(col_pre, col_post, weight_col)

# %%
matrix
# Out:
# type_post  FC1C  FC2A  FC2B  FC2C  FS1A  FS1B  FS3
# type_pre
# FC1C          0     0     5     0    10     0    0
# FC2A          0    20    16     2   194    30    0
# FC2B          0    21   180    59  1212   148    2
# FC2C          1     2    77   158   711   155   20
# FS1A          2     2    42    76  1581    90    5
# FS1B          0     1     0     3    60    23    0
# FS3           0     0     1     1    12     4    5

# %%
matrix.index = matrix.index.astype(str)
matrix.columns = matrix.columns.astype(str)
heatmap = matrix.hvplot.heatmap(xaxis='top', 
                      cmap=('#f7fbff','#deebf7','#c6dbef','#9ecae1','#6baed6','#4292c6','#2171b5', '#084594')).opts(xrotation=30, clim=(0, 1600), width=800, height=600)
# Adding labels for axes
heatmap = heatmap.opts(xlabel='Postsynaptic neurons', ylabel='Presynaptic neurons',
                      title='Connectivity matrix for all FB types that output to oviIN',
                      colorbar=True, colorbar_opts={'title': 'Synaptic Weight'})
heatmap
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# If we take the entire group of cell types that have any members inputting to oviIN, then the picture looks very different. FS1A is not the only type collecting inputs. The PFLs also collect inputs from FC2s. Also, there is more obvious recurrence within each cell type. I'm not sure how to present this but I feel like we should show both figures.

# %%
#creates list of all unique types that input to ovi
#use this list for the connectivity analysis
FB_ovi_input_types = list(FB_ovi_inputs['type_pre'].unique())

# %%
matrix, FB_conns = connectivity_matrix(FB_ovi_input_types)
# Out:
# /Users/ggutierr/anaconda3/envs/modularity/lib/python3.10/site-packages/neuprint/utils.py:304: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   matrix = agg_weights_df.pivot(col_pre, col_post, weight_col)

# %%
matrix
# Out:
# type_post  FC1C  FC2A  FC2B  FC2C  FS1A  FS1B  FS3
# type_pre
# FC1C        869    18    37    58   134    67   26
# FC2A         20   537   140    17  1254   459    6
# FC2B         30   165   413   244  2461   895  109
# FC2C         36    28   250   450  1569   762  315
# FS1A         70     9    71   157  1581   146   23
# FS1B         21     6     2    10   119   246   38
# FS3          11     2    26    58    92    45  760

# %%
matrix.index = matrix.index.astype(str)
matrix.columns = matrix.columns.astype(str)
heatmap = matrix.hvplot.heatmap(xaxis='top', 
                      cmap=('#f7fbff','#deebf7','#c6dbef','#9ecae1','#6baed6','#4292c6','#2171b5', '#084594')).opts(xrotation=30, clim=(0, 1600), width=800, height=600)
# Adding labels for axes
heatmap = heatmap.opts(xlabel='Postsynaptic neurons', ylabel='Presynaptic neurons',
                      title='Connectivity matrix for FB entire types that output to oviIN',
                      colorbar=True, colorbar_opts={'title': 'Synaptic Weight'})
heatmap
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# I thought it would make sense to see all the FB output types and their connectivity. I feel like this should be in the Hulse paper somewhere.

# %%
matrix, FB_conns = connectivity_matrix(FB_output_types)
# Out:
# /Users/ggutierr/anaconda3/envs/modularity/lib/python3.10/site-packages/neuprint/utils.py:304: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   matrix = agg_weights_df.pivot(col_pre, col_post, weight_col)

# %%
matrix.index = matrix.index.astype(str)
matrix.columns = matrix.columns.astype(str)

heatmap = matrix.hvplot.heatmap(xaxis='top', 
                      cmap=('#f7fbff','#deebf7','#c6dbef','#9ecae1','#6baed6','#4292c6','#2171b5', '#084594')).opts(xrotation=30, clim=(0, 1600), width=800, height=600)

# Adding labels for axes
heatmap = heatmap.opts(xlabel='Postsynaptic neurons', ylabel='Presynaptic neurons',
                      title='Connectivity matrix for all FB output types',
                      colorbar=True, colorbar_opts={'title': 'Synaptic Weight'})
heatmap
# Out:
# :HeatMap   [columns,index]   (value)

# %%
hv.save(heatmap, 'figures/FB_output_types_conn_matrix.png', fmt='png')

# %%
ovi_type_inputs[ovi_type_inputs['type_pre']=='FC2A']
# Out:
#     type_pre  weight
# 162     FC2A      24

# %%
test = fetch_simple_connections('FC2B','FS1A')
test
# Out:
#      bodyId_pre  bodyId_post  weight type_pre type_post    instance_pre  \
# 0    1164545788   1014474192      37     FC2B      FS1A  FC2B(FQ7)_C2_L
# 1    1260011966   1291374677      37     FC2B      FS1A  FC2B(FQ7)_C1_R
# 2    1039775880    951808062      30     FC2B      FS1A  FC2B(FQ7)_C6_R
# 3     912583959    915273417      23     FC2B      FS1A  FC2B(FQ7)_C4_L
# 4    1033192275    983430664      23     FC2B      FS1A  FC2B(FQ7)_C3_R
# ..          ...          ...     ...      ...       ...             ...
# 386  5813057464    915964748       1     FC2B      FS1A  FC2B(FQ7)_C7_L
# 387  5813058388   1044918145       1     FC2B      FS1A  FC2B(FQ7)_C2_R
# 388  5813058388   1136252170       1     FC2B      FS1A  FC2B(FQ7)_C2_R
# 389  5813081864   1165305889       1     FC2B      FS1A  FC2B(FQ7)_C9_L
# 390  5813081864   5813130366       1     FC2B      FS1A  FC2B(FQ7)_C9_L
#
#       instance_post                                       conn_roiInfo
# ...

# %%
test.groupby('type_post', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)
# Out:
# /var/folders/qb/p6dbns6n14n6pl5jy5tkwp78xfrsnf/T/ipykernel_69324/2875905652.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   test.groupby('type_post', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)
#   type_post    bodyId_pre   bodyId_post  weight
# 0      FS1A  683576000926  556498120839    2461

# %%
test.groupby('type_pre', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)
# Out:
# /var/folders/qb/p6dbns6n14n6pl5jy5tkwp78xfrsnf/T/ipykernel_69324/3984629475.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   test.groupby('type_pre', as_index=False).sum().sort_values(by='weight', ascending=False, ignore_index=True)
#   type_pre    bodyId_pre   bodyId_post  weight
# 0     FC2B  683576000926  556498120839    2461
