# %% [markdown]
# This notebook fetches the roi structure that Neuprint uses and it creates a dataframe where the columns are the 3 levels of roi hierarchy.

# %%
from neuprint import Client
# remove my token before making notebook public
c = Client('neuprint.janelia.org', dataset='hemibrain:v1.2.1', token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImdnMjExNEBjb2x1bWJpYS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hLS9BT2gxNEdpb1lJLUVPLWdidGxPRTh6SmQ0eF9ZQ1Y4ZHF0YVFjWGlHeG5CMz1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTgxMDUyOTYzNH0.jv9eR0SH5RhfBdXrtp4r-dDFOhcsT8GBbE4v69ysCKs') 
c.fetch_version()

# import important stuff here
import numpy as np
import pandas as pd
import matplotlib

# %%
from neuprint import fetch_roi_hierarchy

# fetch the roi hierarchy
roi_hierarchy = fetch_roi_hierarchy(include_subprimary=True, format = 'text')
print(roi_hierarchy)
# Out:
# hemibrain
#  +-- AL(L)*
#  |   +-- AL-D(L)
#  |   +-- AL-DA2(L)
#  |   +-- AL-DA3(L)
#  |   +-- AL-DA4m(L)
#  |   +-- AL-DC1(L)
#  |   +-- AL-DC2(L)
#  |   +-- AL-DC4(L)
#  |   +-- AL-DL4(L)
#  |   +-- AL-DL5(L)
#  |   +-- AL-DM1(L)
#  |   +-- AL-DM2(L)
#  |   +-- AL-DM3(L)
#  |   +-- AL-DM4(L)
#  |   +-- AL-DM5(L)
#  |   +-- AL-DM6(L)
#  |   +-- AL-DP1m(L)
#  |   +-- AL-VA6(L)
#  |   +-- AL-VM7d(L)
#  |   +-- AL-VM7v(L)
#  +-- AL(R)*
#  |   +-- AL-D(R)
#  |   +-- AL-DA1(R)
#  |   +-- AL-DA2(R)
#  |   +-- AL-DA3(R)
#  |   +-- AL-DA4l(R)
#  |   +-- AL-DA4m(R)
#  |   +-- AL-DC1(R)
#  |   +-- AL-DC2(R)
#  |   +-- AL-DC3(R)
#  |   +-- AL-DC4(R)
#  |   +-- AL-DL1(R)
#  |   +-- AL-DL2d(R)
#  |   +-- AL-DL2v(R)
#  |   +-- AL-DL3(R)
#  |   +-- AL-DL4(R)
#  |   +-- AL-DL5(R)
#  |   +-- AL-DM1(R)
#  |   +-- AL-DM2(R)
#  |   +-- AL-DM3(R)
#  |   +-- AL-DM4(R)
#  |   +-- AL-DM5(R)
#  |   +-- AL-DM6(R)
#  |   +-- AL-DP1l(R)
#  |   +-- AL-DP1m(R)
#  |   +-- AL-V(R)
#  |   +-- AL-VA1d(R)
# ...

# %%
from neuprint import fetch_roi_hierarchy

# fetch the roi hierarchy as a dictionary
roi_hierarchy_dict = fetch_roi_hierarchy(include_subprimary=True, format = 'dict')
roi_hierarchy_dict
# Out:
# {'hemibrain': {'AL(L)*': {'AL-D(L)': {},
#    'AL-DA2(L)': {},
#    'AL-DA3(L)': {},
#    'AL-DA4m(L)': {},
#    'AL-DC1(L)': {},
#    'AL-DC2(L)': {},
#    'AL-DC4(L)': {},
#    'AL-DL4(L)': {},
#    'AL-DL5(L)': {},
#    'AL-DM1(L)': {},
#    'AL-DM2(L)': {},
#    'AL-DM3(L)': {},
#    'AL-DM4(L)': {},
#    'AL-DM5(L)': {},
#    'AL-DM6(L)': {},
#    'AL-DP1m(L)': {},
#    'AL-VA6(L)': {},
#    'AL-VM7d(L)': {},
#    'AL-VM7v(L)': {}},
#   'AL(R)*': {'AL-D(R)': {},
#    'AL-DA1(R)': {},
#    'AL-DA2(R)': {},
#    'AL-DA3(R)': {},
#    'AL-DA4l(R)': {},
#    'AL-DA4m(R)': {},
#    'AL-DC1(R)': {},
#    'AL-DC2(R)': {},
#    'AL-DC3(R)': {},
#    'AL-DC4(R)': {},
#    'AL-DL1(R)': {},
#    'AL-DL2d(R)': {},
#    'AL-DL2v(R)': {},
#    'AL-DL3(R)': {},
#    'AL-DL4(R)': {},
#    'AL-DL5(R)': {},
#    'AL-DM1(R)': {},
#    'AL-DM2(R)': {},
#    'AL-DM3(R)': {},
#    'AL-DM4(R)': {},
#    'AL-DM5(R)': {},
#    'AL-DM6(R)': {},
#    'AL-DP1l(R)': {},
#    'AL-DP1m(R)': {},
# ...

# %%
# turn the dictionary into a dataframe
roi_hierarchy_df = pd.DataFrame(roi_hierarchy_dict)
roi_hierarchy_df
# Out:
#                                                      hemibrain
# AL(L)*       {'AL-D(L)': {}, 'AL-DA2(L)': {}, 'AL-DA3(L)': ...
# AL(R)*       {'AL-D(R)': {}, 'AL-DA1(R)': {}, 'AL-DA2(R)': ...
# AOT(R)                                                      {}
# CX           {'AB(L)*': {}, 'AB(R)*': {}, 'EB*': {'EBr1': {...
# GC                                                          {}
# GF(R)                                                       {}
# GNG*                                                        {}
# INP          {'ATL(L)*': {}, 'ATL(R)*': {}, 'CRE(L)*': {'CR...
# LH(R)*                                                      {}
# LX(L)                            {'BU(L)*': {}, 'LAL(L)*': {}}
# LX(R)        {'BU(R)*': {}, 'LAL(R)*': {'GA(R)': {}, 'LAL(-...
# MB(+ACA)(R)  {'MB(R)': {'CA(R)*': {}, 'PED(R)*': {}, 'a'L(R...
# MB(L)        {'CA(L)*': {}, 'a'L(L)*': {}, 'aL(L)*': {}, 'b...
# OL(R)        {'AME(R)*': {}, 'LO(R)*': {}, 'LOP(R)*': {}, '...
# ...

# %%
# get first row of dataframe
roi_hierarchy_df.iloc[0]
pd.DataFrame(roi_hierarchy_df.iloc[0])
# Out:
#                                                       AL(L)*
# hemibrain  {'AL-D(L)': {}, 'AL-DA2(L)': {}, 'AL-DA3(L)': ...

# %%
# eliminate the 'hemibrain' level of the hierarchy dictionary
roi_hierarchy_dict['hemibrain']
# Out:
# {'AL(L)*': {'AL-D(L)': {},
#   'AL-DA2(L)': {},
#   'AL-DA3(L)': {},
#   'AL-DA4m(L)': {},
#   'AL-DC1(L)': {},
#   'AL-DC2(L)': {},
#   'AL-DC4(L)': {},
#   'AL-DL4(L)': {},
#   'AL-DL5(L)': {},
#   'AL-DM1(L)': {},
#   'AL-DM2(L)': {},
#   'AL-DM3(L)': {},
#   'AL-DM4(L)': {},
#   'AL-DM5(L)': {},
#   'AL-DM6(L)': {},
#   'AL-DP1m(L)': {},
#   'AL-VA6(L)': {},
#   'AL-VM7d(L)': {},
#   'AL-VM7v(L)': {}},
#  'AL(R)*': {'AL-D(R)': {},
#   'AL-DA1(R)': {},
#   'AL-DA2(R)': {},
#   'AL-DA3(R)': {},
#   'AL-DA4l(R)': {},
#   'AL-DA4m(R)': {},
#   'AL-DC1(R)': {},
#   'AL-DC2(R)': {},
#   'AL-DC3(R)': {},
#   'AL-DC4(R)': {},
#   'AL-DL1(R)': {},
#   'AL-DL2d(R)': {},
#   'AL-DL2v(R)': {},
#   'AL-DL3(R)': {},
#   'AL-DL4(R)': {},
#   'AL-DL5(R)': {},
#   'AL-DM1(R)': {},
#   'AL-DM2(R)': {},
#   'AL-DM3(R)': {},
#   'AL-DM4(R)': {},
#   'AL-DM5(R)': {},
#   'AL-DM6(R)': {},
#   'AL-DP1l(R)': {},
#   'AL-DP1m(R)': {},
#   'AL-V(R)': {},
#   'AL-VA1d(R)': {},
#   'AL-VA1v(R)': {},
# ...

# %%
from neuprint import fetch_primary_rois

# fetch the primary rois used by Neuprint
primary_rois = fetch_primary_rois()
print(primary_rois)
# Out:
# ['AB(L)', 'AB(R)', 'AL(L)', 'AL(R)', 'AME(R)', 'AOTU(R)', 'ATL(L)', 'ATL(R)', 'AVLP(R)', 'BU(L)', 'BU(R)', 'CA(L)', 'CA(R)', 'CAN(R)', 'CRE(L)', 'CRE(R)', 'EB', 'EPA(L)', 'EPA(R)', 'FB', 'FLA(R)', 'GNG', 'GOR(L)', 'GOR(R)', 'IB', 'ICL(L)', 'ICL(R)', 'IPS(R)', 'LAL(L)', 'LAL(R)', 'LH(R)', 'LO(R)', 'LOP(R)', 'ME(R)', 'NO', 'PB', 'PED(R)', 'PLP(R)', 'PRW', 'PVLP(R)', 'SAD', 'SCL(L)', 'SCL(R)', 'SIP(L)', 'SIP(R)', 'SLP(R)', 'SMP(L)', 'SMP(R)', 'SPS(L)', 'SPS(R)', 'VES(L)', 'VES(R)', 'WED(R)', "a'L(L)", "a'L(R)", 'aL(L)', 'aL(R)', "b'L(L)", "b'L(R)", 'bL(L)', 'bL(R)', 'gL(L)', 'gL(R)']

# %%
from neuprint import fetch_all_rois

# fetch all rois used by Neuprint
all_rois = fetch_all_rois()
print(all_rois)
# Out:
# ['AB(L)', 'AB(R)', 'AL(L)', 'AL(R)', 'AL-D(L)', 'AL-D(R)', 'AL-DA1(R)', 'AL-DA2(L)', 'AL-DA2(R)', 'AL-DA3(L)', 'AL-DA3(R)', 'AL-DA4l(R)', 'AL-DA4m(L)', 'AL-DA4m(R)', 'AL-DC1(L)', 'AL-DC1(R)', 'AL-DC2(L)', 'AL-DC2(R)', 'AL-DC3', 'AL-DC3(R)', 'AL-DC4(L)', 'AL-DC4(R)', 'AL-DL1(R)', 'AL-DL2d(R)', 'AL-DL2v(R)', 'AL-DL3(R)', 'AL-DL4(L)', 'AL-DL4(R)', 'AL-DL5(L)', 'AL-DL5(R)', 'AL-DM1(L)', 'AL-DM1(R)', 'AL-DM2(L)', 'AL-DM2(R)', 'AL-DM3(L)', 'AL-DM3(R)', 'AL-DM4(L)', 'AL-DM4(R)', 'AL-DM5(L)', 'AL-DM5(R)', 'AL-DM6(L)', 'AL-DM6(R)', 'AL-DP1l(R)', 'AL-DP1m(L)', 'AL-DP1m(R)', 'AL-V(R)', 'AL-VA1d(R)', 'AL-VA1v(R)', 'AL-VA2(R)', 'AL-VA3(R)', 'AL-VA4(R)', 'AL-VA5(R)', 'AL-VA6(L)', 'AL-VA6(R)', 'AL-VA7l(R)', 'AL-VA7m(R)', 'AL-VC1(R)', 'AL-VC2(R)', 'AL-VC3l(R)', 'AL-VC3m(R)', 'AL-VC4(R)', 'AL-VC5(R)', 'AL-VL1(R)', 'AL-VL2a(R)', 'AL-VL2p(R)', 'AL-VM1(R)', 'AL-VM2(R)', 'AL-VM3(R)', 'AL-VM4(R)', 'AL-VM5d(R)', 'AL-VM5v(R)', 'AL-VM7d(L)', 'AL-VM7d(R)', 'AL-VM7v(L)', 'AL-VM7v(R)', 'AL-VP1d(R)', 'AL-VP1l(R)
# ...

# %%
# Writes all rois to a txt file for manual processing
all_r = fetch_all_rois()
# Save to txt file
with open('all_roi.txt', 'w') as f:
    for item in all_r:
        f.write("%s\n" % item)

# %%
# read the file
all_roi = pd.read_csv('all_roi.txt', header=None, names=['roi'], delimiter='\t')
all_roi
# Out:
#            roi
# 0        AB(L)
# 1        AB(R)
# 2        AL(L)
# 3        AL(R)
# 4      AL-D(L)
# ..         ...
# 226  hemibrain
# 227    lACA(R)
# 228    mALT(L)
# 229    mALT(R)
# 230    vACA(R)
#
# [231 rows x 1 columns]

# %% [markdown]
# # testing stuff
# I want to compare the sizes of coarse cluster #3 in the full and input connectomes. Both correspond to the CX.

# %%
# reading in input connectome
ovi_in_node_df = pd.read_csv('ovi_preprocessed/preprocessed_inputs-v1.2.1/preprocessed_nodes.csv')
ovi_in_node_df
# Out:
#               id   key  0.0  0.05  0.1  0.5  0.75  1.0   instance celltype  \
# 0     1003215282     1    1     1    1    1     1    1    CL229_R    CL229
# 1     1005952640     2    2     1    1    2     2    2    IB058_R    IB058
# 2     1006928515     3    1     1    1    3     3    3    CL300_R    CL300
# 3     1007260806     4    2     1    1    4     4    4    CL301_R    CL301
# 4     1008024276     5    3     2    2    5     5    5     FB5N_R     FB5N
# ...          ...   ...  ...   ...  ...  ...   ...  ...        ...      ...
# 2506   987273073  2507    3     8    8  409   604  629  (PVL05)_L     None
# 2507   987842109  2508    3     9   23  533   780  815       None     None
# 2508   988567837  2509    2     3    4   16    58   63     FB4G_R     FB4G
# 2509   988909130  2510    2     3    4  389   559  572     FB5V_R     FB5V
# 2510   989228019  2511    2     3    4  389   559  572     FB5V_R     FB5V
#
# ...

# %%
# reading in full connectome
ovi_full_node_df = pd.read_csv('ovi_preprocessed/preprocessed-v1.2.1/preprocessed_nodes.csv')
ovi_full_node_df
# Out:
#               id   key  0.0  0.05  0.1   0.5  0.75   1.0 instance celltype  \
# 0     1003215282     1    1     1    1     1     1     1  CL229_R    CL229
# 1     1005952640     2    1     1    2     2     2     2  IB058_R    IB058
# 2     1006928515     3    1     1    1     3     3     3  CL300_R    CL300
# 3     1007260806     4    1     2    1     4     4     4  CL301_R    CL301
# 4     1007402796     5    1     1    2     5     5     5  PS119_R    PS119
# ...          ...   ...  ...   ...  ...   ...   ...   ...      ...      ...
# 4544   988269593  4545    3     5    5    95    13  1785   FB4E_L     FB4E
# 4545   988291460  4546    4     4  263  1059  1501  1786     None     None
# 4546   988567837  4547    5     8    7    13    13    13   FB4G_R     FB4G
# 4547   988909130  4548    5     8    7    27    56   436   FB5V_R     FB5V
# 4548   989228019  4549    5     8    7    27    56   241   FB5V_R     FB5V
#
# ...

# %%
in_cluster3 = ovi_in_node_df[ovi_in_node_df['0.0']==3]
in_cluster3
# Out:
#               id   key  0.0  0.05  0.1  0.5  0.75  1.0         instance  \
# 4     1008024276     5    3     2    2    5     5    5           FB5N_R
# 7     1008369339     8    3     2    2    5     5    8   FS1B(FQ9)_C6_R
# 8     1008391068     9    3     2    2    5     5    5   FC2B(FQ7)_C6_L
# 9     1008693605    10    3     2    2    5     5    9   FC2C(FQ7)_C7_L
# 12    1009371535    13    3     2    2    5     5   10   FC2B(FQ7)_C3_L
# ...          ...   ...  ...   ...  ...  ...   ...  ...              ...
# 2496   983771898  2497    3     2    8  430   647  757             None
# 2501   985839488  2502    3    10    5  532   778  821             None
# 2504   986974738  2505    3     8    8   93   116  124  CRE010(ADM03)_L
# 2506   987273073  2507    3     8    8  409   604  629        (PVL05)_L
# 2507   987842109  2508    3     9   23  533   780  815             None
#
#      celltype  ...  status  cropped      statusLabel  cellBodyFiber  \
# ...

# %%
full_cluster3 = ovi_full_node_df[ovi_full_node_df['0.0']==3]
full_cluster3
# Out:
#               id   key  0.0  0.05  0.1  0.5  0.75   1.0        instance  \
# 8     1008024276     9    3     5    5    9     9     9          FB5N_R
# 11    1008369339    12    3     5    5   12    12    12  FS1B(FQ9)_C6_R
# 12    1008378448    13    3     5    5   13    13    13  FB4Y(EB/NO1)_R
# 13    1008378609    14    3     5    5    9    14     9          FB5Y_R
# 14    1008391068    15    3     5    5    9     9    14  FC2B(FQ7)_C6_L
# ...          ...   ...  ...   ...  ...  ...   ...   ...             ...
# 4506   983426636  4507    3     5    5    9    12   107  FS1A(FQ9)_C6_L
# 4507   983430664  4508    3     5    5    9     9    21  FS1A(FQ9)_C3_R
# 4513   983767602  4514    3     5    5    9    12   160  FS1B(FQ9)_C2_L
# 4542   987877232  4543    3     5    5   13    13    13          FB4K_L
# 4544   988269593  4545    3     5    5   95    13  1785          FB4E_L
#
#      celltype  ...  status  cropped     statusLabel  cellBodyFiber  \
# ...

# %%
num_cx_nodes = 0.67*len(full_cluster3)

num_cx_nodes/len(in_cluster3)
# Out:
# 0.4325894378194208

# %% [markdown]
# At best, if all of the CX nodes are in both cluster #3s, then the input connectome cluster #3 would have at least 43% CX. It's possible that not all CX neurons from the full connectome are in the input connectome.

# %%
in_cluster3[in_cluster3['id'].isin(full_cluster3['id'])]
# Out:
#               id   key  0.0  0.05  0.1  0.5  0.75  1.0        instance  \
# 4     1008024276     5    3     2    2    5     5    5          FB5N_R
# 7     1008369339     8    3     2    2    5     5    8  FS1B(FQ9)_C6_R
# 8     1008391068     9    3     2    2    5     5    5  FC2B(FQ7)_C6_L
# 9     1008693605    10    3     2    2    5     5    9  FC2C(FQ7)_C7_L
# 12    1009371535    13    3     2    2    5     5   10  FC2B(FQ7)_C3_L
# ...          ...   ...  ...   ...  ...  ...   ...  ...             ...
# 2487   983067799  2488    3     2    2    5     5   20  FS1A(FQ9)_C3_L
# 2488   983093876  2489    3     2    2    5     5   51  FS1A(FQ9)_C8_L
# 2490   983426636  2491    3     2    2    5     5   77  FS1A(FQ9)_C6_L
# 2491   983430664  2492    3     2    2    5     5   20  FS1A(FQ9)_C3_R
# 2495   983767602  2496    3     2    2    5     5   20  FS1B(FQ9)_C2_L
#
#      celltype  ...  status  cropped     statusLabel  cellBodyFiber  \
# ...

# %% [markdown]
# # main neuropil for each neuron

# %%
# read in Hemibrain connectome
import pandas as pd
import numpy as np

HB_full_node_df = pd.read_csv('hemibrain_preprocessed/preprocessed-v1.2/preprocessed_nodes.csv')
HB_full_node_df
# Out:
#                id  0.75  0.05  0.1  0.25   0.5   1.0  0.0  \
# 0       200326126     1     1    1     1     1     1    1
# 1       202916528     2     2    2     2     2     2    2
# 2       203253072     3     2    3     3     3     3    2
# 3       203253253     4     3    3     4     4     4    2
# 4       203257652     5     2    3     2     2     2    2
# ...           ...   ...   ...  ...   ...   ...   ...  ...
# 21734  7112579856  2322     1    1   157  1064  3243    1
# 21735  7112615127  2670     9   19    46   226  3110    6
# 21736  7112617294  2386     9   19    46   226  3362    6
# 21737  7112622044   879     3    8    14   120  2836    3
# 21738  7112622236  3074    14  171   482  1489   864    3
#
#                   instance celltype  ...        size  status  cropped  \
# 0                  CL141_L    CL141  ...   827930581  Traced    False
# 1          FS4C(FQ12)_C4_R     FS4C  ...   235674230  Traced    False
# ...

# %%
HB_full_node_df['roiInfo'][1]
# Out:
# "{'SNP(L)': {'pre': 93, 'post': 35, 'downstream': 762, 'upstream': 35, 'mito': 39, 'dark': 39}, 'SMP(L)': {'pre': 93, 'post': 35, 'downstream': 762, 'upstream': 35, 'mito': 39, 'dark': 39}, 'CX': {'pre': 1, 'post': 395, 'downstream': 9, 'upstream': 395, 'mito': 34, 'dark': 34}, 'FB': {'pre': 1, 'post': 395, 'downstream': 9, 'upstream': 395, 'mito': 34, 'dark': 34}, 'FBl7': {'pre': 1, 'post': 98, 'downstream': 9, 'upstream': 98, 'mito': 6, 'dark': 6}, 'FBl6': {'post': 96, 'upstream': 96, 'mito': 12, 'dark': 12}, 'FBl8': {'post': 26, 'upstream': 26}, 'FB-column3': {'post': 79, 'upstream': 79, 'mito': 1, 'dark': 1}, 'SNP(R)': {'post': 1, 'upstream': 1}, 'SMP(R)': {'post': 1, 'upstream': 1}, 'FBl5': {'post': 49, 'upstream': 49, 'mito': 6, 'dark': 6}, 'FBl4': {'post': 7, 'upstream': 7, 'mito': 1, 'dark': 1}, 'FBl3': {'post': 20, 'upstream': 20, 'mito': 4, 'dark': 4}, 'FBl2': {'post': 90, 'upstream': 90, 'mito': 5, 'dark': 5}, 'FBl1': {'post': 9, 'upstream': 9}}"

# %%
HB_full_node_df.columns
# Out:
# Index(['id', '0.75', '0.05', '0.1', '0.25', '0.5', '1.0', '0.0', 'instance',
#        'celltype', 'pre', 'post', 'size', 'status', 'cropped', 'statusLabel',
#        'cellBodyFiber', 'somaRadius', 'somaLocation', 'inputRois',
#        'outputRois', 'roiInfo'],
#       dtype='object')
